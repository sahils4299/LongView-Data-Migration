# %% [markdown]
# # Data Migration Notebook Final: Port Folio Testing
# For the demo purpose of Property Tree, we are preparing csv for `Gavin Xu` profile and will be using to give the csv to Property Tree.

# %% [markdown]
# ### We will be loading all the csv from the export to get the properties we will be looling at

# %%
#Importing the libraries
import pandas as pd
properties_before = pd.read_excel('Data Before/Properties_before.xlsx')
tenancies_rps = pd.read_excel('Data Before/Tenancies.xlsx')
contacts_rps = pd.read_excel('Data Before/Contacts.xlsx')
companies_rps = pd.read_excel('Data Before/Companies.xlsx')
landlord_rps = pd.read_excel('Data Before/Landlord.xlsx')

# %%
rent_renewals_rps = pd.read_excel("Data Before/Kasey rent Renewals .xlsx")

# %%
### GEtting the ORiinal straat date and start date
rent_renewals_rps['Tenancy Start'] = pd.to_datetime(rent_renewals_rps['Tenancy Start'])
rent_renewals_rps['Start date'] = pd.to_datetime(rent_renewals_rps['Start date'])

# Group by 'Category' and get the maximum date within each group
rent_renewals_rps = rent_renewals_rps[rent_renewals_rps.groupby('Short property address')['Start date'].transform('max') == rent_renewals_rps['Start date']]
for index,row in properties_before.iterrows():
    try:
        temp = rent_renewals_rps[rent_renewals_rps['Short property address'] == row['Short Address']]
        properties_before.loc[index,'Tenancy_Start'] = temp['Tenancy Start'].iloc[0]
        properties_before.loc[index,'Start_date'] = temp['Start date'].iloc[0]
    except:
        continue
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\1580687788.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rent_renewals_rps['Tenancy Start'] = pd.to_datetime(rent_renewals_rps['Tenancy Start'])
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\1580687788.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rent_renewals_rps['Start date'] = pd.to_datetime(rent_renewals_rps['Start date'])

# %% [markdown]
# # 0 . Accounts.csv

# %%
accounts_rps = pd.read_excel('Data Before/Accounts.xlsx')

# %%
accounts_rps
# Out:
#                             Landlord  \
# 0      Irmgard Chia - Irmale Pty Ltd
# 1      Irmgard Chia - Irmale Pty Ltd
# 2      Irmgard Chia - Irmale Pty Ltd
# 3      Irmgard Chia - Irmale Pty Ltd
# 4      Irmgard Chia - Irmale Pty Ltd
# ...                              ...
# 24505             Steven Stronghilis
# 24506             Steven Stronghilis
# 24507             Steven Stronghilis
# 24508         Alexandre Francis Catu
# 24509         Alexandre Francis Catu
#
#                                         Property       Date  \
# 0          32 Lynch Street, Footscray, VIC, 3011 2023-07-04
# 1          32 Lynch Street, Footscray, VIC, 3011 2023-07-04
# 2          32 Lynch Street, Footscray, VIC, 3011 2023-07-04
# 3          32 Lynch Street, Footscray, VIC, 3011 2023-07-04
# 4          32 Lynch Street, Footscray, VIC, 3011 2023-07-06
# ...                                          ...        ...
# 24505    4/4 Orange Street, Braybrook, VIC, 3019 2023-07-13
# ...

# %%
code_description = {
    'gardng': 'Gardening',
    'cleann': 'Cleaning',
    'debtor': 'Debtors Account',
    'crdtor': 'Creditors Account',
    'clnbnk': 'Bank Charges',
    'blinds': 'Blinds',
    'Poolmt': 'Pool Maintenance',
    'lldacc': 'Landlord Account',
    'manren': 'Management Renewal Fee',
    'rntinc': 'Rental Income',
    'genman': 'General Maintenance',
    'eofysf': 'EOFY Statement Fee',
    'actadm': 'Accounts Admin Fee',
    'manfee': 'Management Fee',
    'depinc': 'Deposit Income',
    'electn': 'Electrical Repairs',
    'waterr': 'Water Rates',
    'apprep': 'Appliance Repairs',
    'smkala': 'Smoke Alarm',
    'stmfee': 'Statement Fee',
    'advert': 'Advertising Fee',
    'leafee': 'Leasing Fee',
    'plumng': 'Plumbing',
    'recfee': 'Recurring Admin Fees',
    'elegas': 'Gas Charges',
    'ocfees': 'Owners Corporation Fees',
    'insure': 'Insurance',
    'postag': 'Postage',
    'dishon': 'Dishonour Fee',
    'learen': 'Leasing Renewal Fee',
    'cnlrts': 'Council Rates',
    'loanac': 'Loan Account',
    'tnttrn': 'Tenant Transfer Fee',
    'keyacc': 'Keys and Remotes',
    'leabrk': 'Lease Break Fee',
    'genexp': 'General Expenses',
    'htgclg': 'Heating & Cooling',
    'landtx': 'Land Tax',
    'lldflt': 'Landlord Float',
    'pmgfee': 'Project Management Fee',
    'rengif': 'Renter Gift',
    'glazng': 'Glazing Charges',
    'lldadm': 'Landlord Admin Charge',
    'electr': 'Electricity Usage',
    'gutcln': 'Gutter Cleaning',
    'vcatfe': 'VCAT Fee',
    'compen': 'Compensation',
    'adjacc': 'Adjustment Account',
    'reimbu': 'Reimbursements',
    'badfee': 'Cancellation Fee',
    'intrnt': 'Internet',
    'pstctl': 'Credit Card Fee',
    'remstr': 'Removals and Storage',
    'garrep': 'Garage Repairs',
    'lcksmt': 'Locksmith',
    'matfee': 'Management Renewal Fee',
    'floorg': 'Flooring',
    'bndclm': 'Bond Claim',
    'fencin': 'Fencing',
    'keysacc': "Keys account",
    'regmai' : 'Registered Mail',
    'keycut' : 'key cutting',
    'virtou' : "Virtual Tour",
    'virsty' : "Virtual Styling",
    'propho' : 'Professioanl Photography',
    'flopln' : "Floorplan"


}
financial_transactions = ['debtor', 'crdtor', 'clnbnk', 'depinc', 'rntinc', 'adjacc', 'actadm','lldacc','loanac','lldflt','bndclm']

property_maintenance = ['gardng', 'cleann', 'Poolmt', 'genman', 'apprep', 'electn', 'plumng',
                        'garrep', 'glazng', 'gutcln', 'lcksmt', 'floorg', 'fencin', 'smkala','keyacc']

fees_and_charges = ['eofysf','stmfee', 'advert', 'manfee', 'leafee', 'learen', 'dishon', 'vcatfe',
                    'badfee', 'matfee', 'pstctl', 'remstr','regmai','keycut','virtou','virsty','propho','flopln','tnttrn','leabrk','manren','recfee','pmgfee','lldadm']

utilities_and_services = ['waterr', 'insure', 'postag', 'electr', 'intrnt','elegas','htgclg']

legal_and_compliance = [ 'ocfees', 'cnlrts', 'landtx']

miscellaneous = ['blinds', 'smkala', 'keysacc', 'reimbu', 'genexp', 'rengif', 'compen']

data = [(code, 'financial_transactions', code_description[code]) for code in financial_transactions] + \
       [(code, 'property_maintenance', code_description[code]) for code in property_maintenance] + \
       [(code, 'fees_and_charges', code_description[code]) for code in fees_and_charges] + \
       [(code, 'utilities_and_services', code_description[code]) for code in utilities_and_services] + \
       [(code, 'legal_and_compliance', code_description[code]) for code in legal_and_compliance] + \
       [(code, 'miscellaneous', code_description[code]) for code in miscellaneous]

# Create the DataFrame
df_accounts = pd.DataFrame(data, columns=['code', 'parent_code', 'name'])
df_accounts['gst'] = ''

# %%
# Create a dictionary to store the codes for each list
list_codes = {}

# Function to generate a 6-digit code for each list
def generate_list_code():
    return str((len(list_codes)+1) * 100000).zfill(6)

# Function to generate a code for each key in the list
def generate_key_code(list_code, index):
    if (index + 1) >= 10:
        return f"{list_code[0:4]}{str(index + 1)}"
    else:
        return f"{list_code[0:5]}{str(index + 1)}"
    
# Generate codes for each list
list_codes['financial_transactions'] = generate_list_code()
list_codes['property_maintenance'] = generate_list_code()
list_codes['fees_and_charges'] = generate_list_code()
list_codes['utilities_and_services'] = generate_list_code()
list_codes['legal_and_compliance'] = generate_list_code()
list_codes['miscellaneous'] = generate_list_code()

# %%
# Generate codes for keys inside each list and update the code_description dictionary
for list_name, list_keys in [('financial_transactions', financial_transactions),
                             ('property_maintenance', property_maintenance),
                             ('fees_and_charges', fees_and_charges),
                             ('utilities_and_services', utilities_and_services),
                             ('legal_and_compliance', legal_and_compliance),
                             ('miscellaneous', miscellaneous)]:
    list_code = list_codes[list_name]
    for index, key in enumerate(list_keys):
        code_description[key] = generate_key_code(list_code, index)

# %%
for index,row in df_accounts.iterrows():
    df_accounts.loc[index,'code'] = code_description[row['code']]
    df_accounts.loc[index,'parent_code'] = list_codes[row['parent_code']]

# %%
df_accounts['name'].unique()
# Out:
# array(['Debtors Account', 'Creditors Account', 'Bank Charges',
#        'Deposit Income', 'Rental Income', 'Adjustment Account',
#        'Accounts Admin Fee', 'Landlord Account', 'Loan Account',
#        'Landlord Float', 'Bond Claim', 'Gardening', 'Cleaning',
#        'Pool Maintenance', 'General Maintenance', 'Appliance Repairs',
#        'Electrical Repairs', 'Plumbing', 'Garage Repairs',
#        'Glazing Charges', 'Gutter Cleaning', 'Locksmith', 'Flooring',
#        'Fencing', 'Smoke Alarm', 'Keys and Remotes', 'EOFY Statement Fee',
#        'Statement Fee', 'Advertising Fee', 'Management Fee',
#        'Leasing Fee', 'Leasing Renewal Fee', 'Dishonour Fee', 'VCAT Fee',
#        'Cancellation Fee', 'Management Renewal Fee', 'Credit Card Fee',
#        'Removals and Storage', 'Registered Mail', 'key cutting',
#        'Virtual Tour', 'Virtual Styling', 'Professioanl Photography',
#        'Floorplan', 'Tenant Transfer Fee', 'Lease Break Fee',
# ...

# %%
df_accounts.to_excel('PropertyTree Data/PropertyTree_Accounts.xlsx',index=False)

# %% [markdown]
# ## 1. Preparing the properties

# %%
"""
Function to call the properties using API from RPS 
Link : https://webservice.reapit.net.au/lng/rest/_doc/?ApiKey=c242c818604a72582f383ba23b2853d1&ClearCache=T#/Landlord/get_properties__ID__inspections

"""

import requests
from pandas.io.json import json_normalize

def get_property_details(prop_id):
    url = f"https://webservice.reapit.net.au/lng/rest/properties/rps_lng-{prop_id}"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/properties/rps_lng-{prop_id}?GetUnavailable=true"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
# Creating a dataframe for Properties

df_properties = pd.DataFrame()
for prop_id in properties_before[properties_before['Agent Name'] == 'Kasey Neuendorf']['Reference'].tolist():
    #print(prop_id)
    result = get_property_details(prop_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        
        # Append the DataFrame to df_result
        df_properties = df_properties.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3261955583.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3261955583.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_properties = df_properties.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3261955583.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3261955583.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_properties = df_properties.append(df, ignore_index=True)
# ...

# %%
df_properties.shape
# Out:
# (341, 68)

# %%
df_properties[df_properties['Type'].isnull()]['HouseNumber']
# Out:
# Series([], Name: HouseNumber, dtype: object)

# %% [markdown]
# ### 1.1 Generating CSV for properties

# %%
df_properties['Type'] = df_properties['Type'].apply(lambda x: x if str(x) =='nan' else x[0])
for index, row in df_properties.iterrows():
    if str(row['Type']) =='nan':
        df_properties.loc[index,'Type'] = 'Unit/Apartment' if '/' in row['HouseNumber'] else 'House'
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2612136547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_properties['Type'] = df_properties['Type'].apply(lambda x: x if str(x) =='nan' else x[0])

# %%
# Removing Property Type 'Car Space'
#df_properties = df_properties[df_properties['ID'] != 'rps_lng-CVA210304']
# if not df_properties['Type'].empty:
#     df_properties['Type'] = df_properties['Type'].explode()
df_properties['Type']  = df_properties['Type'].apply(lambda x: x.split('/')[1] if x =='Unit/Apartment' else x)
# Creating the lookup field for properties
df_properties['Type'] = df_properties['Type'].apply(lambda x: " Residential_" + x + " ")
property_rent_period_lookup = ["Daily", "Weekly", "Fortnightly", "Monthly", "Quarterly", "Yearly", "SquareMeterMonthly", "SquareMeterYearly"]
df_properties['RentalPeriod'] = df_properties['RentalPeriod'].apply(lambda x: next((match for match in property_rent_period_lookup if match.lower().__contains__(x)), x))
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\1843754620.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_properties['Type']  = df_properties['Type'].apply(lambda x: x.split('/')[1] if x =='Unit/Apartment' else x)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\1843754620.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_properties['Type'] = df_properties['Type'].apply(lambda x: " Residential_" + x + " ")
# ...

# %%
df_properties= df_properties[(df_properties['LettingStatus'] != 'Withdrawn') & (df_properties['LettingStatus'] != 'Provisional')]

# %%
len(df_properties['ID'].unique())
# Out:
# 261

# %%
df_fees
# Out:
#    fee_id                    name                        fee_type  \
# 0       1          Management Fee  Property_Percent_RentReceipted
# 1       2             Leasing Fee     Property_Percent_NewTenancy
# 2       3         Advertising Fee        Property_Flat_NewTenancy
# 3       4  Management Renewal Fee   Property_Percent_LeaseRenewal
# 4       5     Tenant Transfer Fee             Tenancy_Flat_Manual
# 5       6      Accounts Admin Fee            Property_Flat_Manual
# 6       7      EOFY Statement Fee            Property_Flat_Manual
#
#   account_code   applies_to applies_to_new  amount  include_gst
# 0       300004  Residential    Residential     6.6            1
# 1       300005  Residential    Residential     2.2            1
# 2       300003  Residential    Residential   400.0            1
# 3       300010  Residential    Residential   220.0            1
# 4       300019  Residential    Residential     5.5            1
# ...

# %%
#fees_monday
fees_monday_dict = fees_monday.set_index('RPS Property Code').to_dict(orient='index')

# %%
fees_monday_dict
# Out:
# {'HDO210296': {'Name': '503/18 Hoff Boulevard, Southbank, VIC, 3006',
#   'Subitems': nan,
#   'Person': nan,
#   'PM': 'Kasey Neuendorf',
#   'Authority': 'Saved',
#   'Management %': 7,
#   'Letting': 1.5,
#   'Weeks or %': 'Weeks rent',
#   'GST': 'Exc GST',
#   'Advertising': 'At Cost',
#   'Renewal': '$200 inc GST',
#   'TT Transfer': '$220 inc gst',
#   'Admin': '$5.50 inc gst',
#   'EOFY Statement': '30 + gst',
#   'Leasing cancellation': '1 Week Rent + GST',
#   'Compliance': nan,
#   'Status': 'Complete',
#   'Text': nan},
#  'HDO210242': {'Name': '1 Third Avenue, Hoppers Crossing, VIC, 3029',
#   'Subitems': nan,
#   'Person': 'Valerie Ann Roa',
#   'PM': 'Kasey Neuendorf',
#   'Authority': 'Saved',
#   'Management %': 6,
#   'Letting': 1.5,
#   'Weeks or %': 'Weeks rent',
#   'GST': 'Exc GST',
#   'Advertising': 'At cost - Current Rate: Advertising $240.',
#   'Renewal': '$100 inc GST',
#   'TT Transfer': '$165.00 (to be reimbursed by Renters)',
# ...

# %%
df_properties_mapping = {
    'property_id': 'ID',
    'ownership_id': 'Landlord_ID',
    'property_type': 'Type',
    'unit': 'HouseNumber',
    'street_no': 'HouseNumber',
    'street_1': 'Address1',
    'street_2': '',
    'suburb': 'Address3',
    'state': 'Address4',
    'postcode': 'Postcode',
    'bedrooms': 'Bedroom',
    'bathrooms': 'Bathroom',
    'car_spaces': 'CarSpace',
    'lot_no': '',
    'area': 'Size',
    'authority_start': 'DateMarketed',
    'authority_end': '',
    'gained': 'TimeAmended',
    'gained_reason': '',
    'rent_account': '',
    'rent_description': '',
    'rent_amount': 'WeeklyRent',
    'rent_period': 'RentalPeriod',
    'outgoings_[n]_account': '',
    'outgoings_[n]_description': '',
    'outgoings_[n]_amount': '',
    'tag_[group name]': '',
    'fee_1': '',
    'fee_2': '',
    'fee_3': '',
    'fee_4': '',
    'fee_5': '',
    'fee_6': '',
    'fee_7': '',
    'Property Manager' : 'Negotiator_Name'
}
pt_df_properties = pd.DataFrame()
for key,value in df_properties_mapping.items():
    if value != '':
        pt_df_properties[key] = df_properties[value]
    else:
        pt_df_properties[key] = ''

# pt_df_properties['property_type'] = "Residential_House"
# pt_df_properties['rent_period'] = pt_df_properties['rent_period'].replace({'month': "Monthly",'week':"Weekly"})

# Getting the unit and street no from the HouseNumber
pt_df_properties['unit'] = pt_df_properties['unit'].apply(lambda x: x.split('/')[0] if x.__contains__('/') else '')
pt_df_properties['street_no'] = pt_df_properties['street_no'].apply(lambda x: x.split('/')[1] if x.__contains__('/') else x)
pt_df_properties['rent_account'] = 100005

# %%
for index, row in pt_df_properties.iterrows():
    property_id = row['property_id'].split('_lng-')[1]
    
    if property_id in fees_from_rps_export:
        management_fee = fees_from_rps_export[property_id]['Management Fee %']
        let_commission = fees_from_rps_export[property_id]['Let Commission']
        eofy_statement_fee = fees_from_rps_export[property_id]['EOFY Statement Fee']
        
        if management_fee and let_commission and eofy_statement_fee != ' ':
            pt_df_properties.loc[index, 'fee_1'] = round(float(management_fee) * 1.1, 2)
            pt_df_properties.loc[index, 'fee_2'] = round(float(let_commission) * 110, 2)
            pt_df_properties.loc[index, 'fee_7'] = round(float(eofy_statement_fee), 2)
        else:
            pt_df_properties.loc[index, 'fee_1'] = None
            pt_df_properties.loc[index, 'fee_2'] = None
            pt_df_properties.loc[index, 'fee_7'] = None
    else:
        pt_df_properties.loc[index, 'fee_1'] = None
        pt_df_properties.loc[index, 'fee_2'] = None
        pt_df_properties.loc[index, 'fee_7'] = None

# %%
pt_df_properties
# Out:
#            property_id       ownership_id    property_type unit street_no  \
# 0    rps_lng-CVA210023  rps_lng-CVA210015   Residential_              35A
# 1    rps_lng-CVA210032  rps_lng-CVA210020   Residential_              124
# 3    rps_lng-CVA210067  rps_lng-CVA210054   Residential_    904         1
# 4    rps_lng-CVA210068  rps_lng-CVA210055   Residential_     33        88
# 5    rps_lng-CVA210071  rps_lng-CVA210058   Residential_     31        88
# ..                 ...                ...              ...  ...       ...
# 335  rps_lng-HDO230195  rps_lng-HDO210026   Residential_               68
# 336  rps_lng-HDO230247  rps_lng-HDO230215   Residential_      3        59
# 337  rps_lng-HDO230259  rps_lng-HDO220600   Residential_      1         1
# 338  rps_lng-HDO230287  rps_lng-HDO230246   Residential_               10
# 339  rps_lng-HDO230313  rps_lng-HDO190525   Residential_               15
#
#                street_1 street_2       suburb state postcode  ...  \
# ...

# %%
for index, row in pt_df_properties.iterrows():
    property_id = row['property_id'].split('_lng-')[1]
    
    if property_id in fees_monday_dict:
        management_percentage = fees_monday_dict[property_id]['Management %']
        letting_fee = fees_monday_dict[property_id]['Letting']
        
        pt_df_properties.loc[index, 'fee_1'] = round(float(management_percentage) * 1.1, 2)
        pt_df_properties.loc[index, 'fee_2'] = round(float(letting_fee) * 1.1, 2)
    # else case is omitted, leaving the columns as they are

# %%
pt_df_properties['rent_amount'] = round(pt_df_properties['rent_amount'],2)
pt_df_properties['authority_start'] = pd.to_datetime('1999-01-01', format='%Y-%m-%d')

#pt_df_properties['PM'] = 'Kasey '


# For reference 
'''
    pt_df_properties.loc[index,'fee_1'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Management %'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 6.6
    pt_df_properties.loc[index,'fee_2'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Letting'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 2.2
    pt_df_properties.loc[index,'fee_3'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Advertising'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 400.00
    pt_df_properties.loc[index,'fee_4'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Renewal'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 220.0
    pt_df_properties.loc[index,'fee_5'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['TT Transfer'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 5.5
    pt_df_properties.loc[index,'fee_6'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Admin'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 5.5
    pt_df_properties.loc[index,'fee_7'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['EOFY Statement'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 30.0
'''
# Out:
# "\n    pt_df_properties.loc[index,'fee_1'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Management %'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 6.6\n    pt_df_properties.loc[index,'fee_2'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Letting'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 2.2\n    pt_df_properties.loc[index,'fee_3'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Advertising'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 400.00\n    pt_df_properties.loc[index,'fee_4'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['Renewal'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 220.0\n    pt_df_properties.loc[index,'fee_5'] = fees_monday_dict[row['property_id'].split('_lng-')[1]]['TT Transfer'] if row['property_id'].split('_lng-')[1] in fees_monday_dict.keys() else 5.5\n    pt_df_properties.loc[index,'fee_6'] = fees_monda
# ...

# %%
pt_df_properties
# Out:
#            property_id       ownership_id    property_type unit street_no  \
# 0    rps_lng-CVA210023  rps_lng-CVA210015   Residential_              35A
# 1    rps_lng-CVA210032  rps_lng-CVA210020   Residential_              124
# 3    rps_lng-CVA210067  rps_lng-CVA210054   Residential_    904         1
# 4    rps_lng-CVA210068  rps_lng-CVA210055   Residential_     33        88
# 5    rps_lng-CVA210071  rps_lng-CVA210058   Residential_     31        88
# ..                 ...                ...              ...  ...       ...
# 335  rps_lng-HDO230195  rps_lng-HDO210026   Residential_               68
# 336  rps_lng-HDO230247  rps_lng-HDO230215   Residential_      3        59
# 337  rps_lng-HDO230259  rps_lng-HDO220600   Residential_      1         1
# 338  rps_lng-HDO230287  rps_lng-HDO230246   Residential_               10
# 339  rps_lng-HDO230313  rps_lng-HDO190525   Residential_               15
#
#                street_1 street_2       suburb state postcode  ...  \
# ...

# %% [markdown]
# # 1.1.2 Getting current Tenancies of the properties

# %%
def get_property_cur_tenancies(prop_id):
    url = f"https://webservice.reapit.net.au/lng/rest/properties/rps_lng-{prop_id}/tenancy/current"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/properties/rps_lng-{prop_id}?GetUnavailable=true/tenancy/current"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_properties_cur_tenancies = pd.DataFrame()
for prop_id in properties_before[properties_before['Agent Name'] == 'Kasey Neuendorf']['Reference'].tolist():
    result = get_property_cur_tenancies(prop_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        df.insert(0, 'prop_id', prop_id)
        
        # Append the DataFrame to df_result
        df_properties_cur_tenancies = df_properties_cur_tenancies.append(df, ignore_index=True)
df_properties_cur_tenancies
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\843250621.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\843250621.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_properties_cur_tenancies = df_properties_cur_tenancies.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\843250621.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\843250621.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_properties_cur_tenancies = df_properties_cur_tenancies[df_properties_cur_tenancies['Status'] == 'Tenancy Current']

# %% [markdown]
# # Generating csv for properties here so that only properties with Tenancy current get converted to csv

# %%
pt_df_properties = pt_df_properties[pt_df_properties['property_id'].isin(['rps_lng-' + x for x in df_properties_cur_tenancies['prop_id'].tolist()])]

# %%
len(set(df_properties_cur_tenancies['prop_id'].tolist())),len(pt_df_properties)
# Out:
# (258, 258)

# %%
pt_df_properties.to_csv('PropertyTree Data/PropertyTree_Properties.csv',index = False)

# %% [markdown]
# ### 1.2 Getting Properties Transactions

# %%
def get_property_transactions(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/tenant/tenancies/{tenancy_id}/transactions"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/tenant/tenancies/{tenancy_id}?GetUnavailable=true/transactions"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_properties_transactions = pd.DataFrame()
for tenancy_id in df_properties_cur_tenancies['ID'].tolist():
    result = get_property_transactions(tenancy_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        df.insert(0, 'tenancy_id', tenancy_id)
        
        # Append the DataFrame to df_result
        df_properties_transactions = df_properties_transactions.append(df, ignore_index=True)
df_properties_transactions
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3927679021.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3927679021.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_properties_transactions = df_properties_transactions.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3927679021.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3927679021.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# # Getting the rent and extracting paid_to date and rent_credit

# %%
df_properties_transactions_rent = df_properties_transactions[df_properties_transactions['Category'] == 'Rent']
df_properties_transactions_tenant_payment = df_properties_transactions[df_properties_transactions['Category'] == 'Tenant Payment']

df_properties_transactions_rent_latest = df_properties_transactions_rent.groupby('tenancy_id').tail(1)
df_properties_transactions_tenant_payment_latest = df_properties_transactions_tenant_payment.groupby('tenancy_id').tail(1)

# %%
df_tenancies_transaction = pd.concat([df_properties_transactions_rent_latest, df_properties_transactions_tenant_payment_latest]).drop_duplicates().sort_values('tenancy_id').reset_index(drop=True)

# %%
import re
date_pattern = r'\d{2}/\d{2}/\d{4}'  # Regular expression pattern for dates
for index, row in df_tenancies_transaction.iterrows():
    if row['Category'] == 'Rent':
        dates = re.findall(date_pattern, row['Description'])
        if len(dates) >= 2:
            df_tenancies_transaction.loc[index, 'Rent_paid_to'] = dates[1]
    if row['Category'] == 'Tenant Payment':
        df_tenancies_transaction.loc[index, 'Rent_credit'] = row['Balance'] if float(row['Balance']) > 0 else 0

# %%
# df_tenancies_transaction.to_csv('Rent paid to check and credit.csv',index = False)

# %%
df_tenancies_transaction
# Out:
#             tenancy_id                   ID                   DateTime  \
# 0    rps_lng-CHA190010  rps_lng-HDO23326711  2023-08-01T00:00:00+01:00
# 1    rps_lng-CHA190010  rps_lng-HDO23324551  2023-07-25T00:00:00+01:00
# 2    rps_lng-CVA210093  rps_lng-HDO23325659  2023-08-01T00:00:00+01:00
# 3    rps_lng-CVA210093  rps_lng-HDO23337205  2023-08-01T00:00:00+01:00
# 4    rps_lng-CVA210098  rps_lng-HDO23325941  2023-08-01T00:00:00+01:00
# ..                 ...                  ...                        ...
# 510  rps_lng-SAN210008  rps_lng-HDO23350629  2023-08-15T00:00:00+01:00
# 511  rps_lng-SAN220057  rps_lng-HDO23327225  2023-08-01T00:00:00+01:00
# 512  rps_lng-SAN220057  rps_lng-HDO23324531  2023-07-25T00:00:00+01:00
# 513  rps_lng-WES200030  rps_lng-HDO23340940  2023-08-03T00:00:00+01:00
# 514  rps_lng-WES200030  rps_lng-HDO23319991  2023-07-27T00:00:00+01:00
#
#         Type        Category  \
# 0    Invoice            Rent
# 1    Payment  Tenant Payment
# ...

# %% [markdown]
# # 2. Tenancies.csv

# %%
import requests

def get_tenancy_details(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/tenancies?GetUnavailable=true/{tenancy_id}"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_tenancies = pd.DataFrame()
for tenancy_id in df_properties_cur_tenancies['ID'].tolist():
    #print(tenancy_id)
    result = get_tenancy_details(tenancy_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        
        # Append the DataFrame to df_result
        df_tenancies = df_tenancies.append(df, ignore_index=True)

df_tenancies = df_tenancies[df_tenancies['Status'].isin(['Tenancy Current'])]

# Print the final DataFrame
#print(df_result)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\4293390169.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\4293390169.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tenancies = df_tenancies.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\4293390169.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\4293390169.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tenancies = df_tenancies.append(df, ignore_index=True)
# ...

# %%
df_tenancies_transaction
# Out:
#             tenancy_id                   ID                   DateTime  \
# 0    rps_lng-CHA190010  rps_lng-HDO23326711  2023-08-01T00:00:00+01:00
# 1    rps_lng-CHA190010  rps_lng-HDO23324551  2023-07-25T00:00:00+01:00
# 2    rps_lng-CVA210093  rps_lng-HDO23325659  2023-08-01T00:00:00+01:00
# 3    rps_lng-CVA210093  rps_lng-HDO23337205  2023-08-01T00:00:00+01:00
# 4    rps_lng-CVA210098  rps_lng-HDO23325941  2023-08-01T00:00:00+01:00
# ..                 ...                  ...                        ...
# 510  rps_lng-SAN210008  rps_lng-HDO23350629  2023-08-15T00:00:00+01:00
# 511  rps_lng-SAN220057  rps_lng-HDO23327225  2023-08-01T00:00:00+01:00
# 512  rps_lng-SAN220057  rps_lng-HDO23324531  2023-07-25T00:00:00+01:00
# 513  rps_lng-WES200030  rps_lng-HDO23340940  2023-08-03T00:00:00+01:00
# 514  rps_lng-WES200030  rps_lng-HDO23319991  2023-07-27T00:00:00+01:00
#
#         Type        Category  \
# 0    Invoice            Rent
# 1    Payment  Tenant Payment
# ...

# %% [markdown]
# ### 2.2 Generating CSV for Tenancies

# %%
for index,row in df_tenancies.iterrows():
    try:
        temp = properties_before[properties_before['Reference'] == row['Property_ID'].split('_lng-')[1]]
        df_tenancies.loc[index,'Tenancy_Start'] = temp['Tenancy_Start'].iloc[0]
        df_tenancies.loc[index,'Start_date'] = temp['Start_date'].iloc[0]
        
    except:
        continue

# %%
df_tenancies_mapping = {
    'tenancy_id': 'ID',
    'property_id': 'Property_ID',
    'original_lease_start': 'Tenancy_Start',
    'lease_start': 'StartDate', 
    'lease_end': 'EndDate',
    'vacate_type': '',
    'notice_sent_received': '',
    'termination_date': '',
    'moving_out': '',
    'charge_to': '',
    'contact_1_id': 'Tenant_ID',
    'contact_[n]_auto_email_receipts': '',
    'contact_[n]_auto_email_invoices': '',
    'contact_[n]_enotices_no_consent': '',
    'contact_[n]_dont_send_marketing': '',
    'contact_[n]_type': '',
    'contact_[n]_account_name': '',
    'contact_[n]_account_bsb': '',
    'contact_[n]_account_no': '',
    'direct_debit_invoices': '',
    'direct_debit_rent': '',
    'direct_debit_contact_id': '',
    'direct_debit_max_amount': '',
    'direct_debit_schedule_description': '',
    'direct_debit_schedule_period': '',
    'direct_debit_schedule_amount': '',
    'direct_debit_schedule_start': '',
    'direct_debit_schedule_end': '',
    'last_rent_review': 'LastRentReview_DateTime',
    'next_rent_review': 'NextRentReview_DateTime',
    'rent_account': '',
    'rent_description': '',
    'rent_start': 'Start_date',
    'rent_period': 'RentPeriod',
    'rent_amount': 'WeeklyRent',
    'new_rent_start': '',
    'new_rent_period': '',
    'new_rent_amount': '',
    'rent_paid_to': '',
    'rent_credit': '',
    'outgoings_[n]_account': '',
    'outgoings_[n]_description': '',
    'outgoings_[n]_amount': '',
    'outgoings_[n]_paid_to': '',
    'outgoings_[n]_credit': '',
    'new_outgoings_[n]_amount': '',
    'bond_[n]_required': '',
    'bond_[n]_account': '',
    'bond_[n]_reference': '',
    'bond_[n]_lodged_direct': '',
    'held_for_tenancy': '',
    'tag_[group name]': '',
    'fee_[fee id]': ''
}
pt_df_tenancies = pd.DataFrame()

for key, value in df_tenancies_mapping.items():
    if value != '':
        pt_df_tenancies[key] = df_tenancies[value]
    else:
        pt_df_tenancies[key] = ''

for index,row in df_tenancies.iterrows():
    if str(row['JointTenant']) != 'nan':
        for i in range(len(row['JointTenant'])):
            pt_df_tenancies.loc[index,f"contact_{i+2}_id"] = row['JointTenant'][i]['ID']

pt_df_tenancies['rent_period'] = pt_df_tenancies['rent_period'].apply(lambda x: next((match for match in property_rent_period_lookup if match.lower().__contains__(x)), x))
pt_df_tenancies['rent_account'] = 100005
pt_df_tenancies['rent_amount'] = pt_df_tenancies['rent_amount'].apply(lambda x:round(float(x),2))

for index, row in pt_df_tenancies.iterrows():
    temp = df_tenancies_transaction[df_tenancies_transaction['tenancy_id'] == row['tenancy_id']]
    rent_paid_to = None
    rent_credit = 0.0

    for desc in temp['Rent_paid_to'].tolist():
        if str(desc) != 'nan':
            rent_paid_to = desc

    for desc in temp['Rent_credit'].tolist():
        if str(desc) != 'nan':
            rent_credit = desc

    pt_df_tenancies.loc[index, 'rent_paid_to'] = rent_paid_to
    pt_df_tenancies.loc[index, 'rent_credit'] = rent_credit
    if str(row['original_lease_start']) == 'NaT':
        pt_df_tenancies.loc[index,'original_lease_start'] = pt_df_tenancies.loc[index,'lease_start']
    if str(row['rent_start'])== 'NaT':
        pt_df_tenancies.loc[index,'rent_start'] = pt_df_tenancies.loc[index,'lease_start']




pt_df_tenancies.to_csv("PropertyTree Data/PropertyTree_Tenancies.csv",index = False)

# %% [markdown]
# ### 2.3 Getting the Rent reviews for tenancies

# %%
import requests

def get_tenancies_rent_reviews(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}/rentReviews"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}?GetUnavailable=true/rentReviews"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_tenancies_rent_reviews = pd.DataFrame()
for tenancy_id in df_tenancies['ID'].tolist():
    result = get_tenancies_rent_reviews(tenancy_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        
        # Append the DataFrame to df_result
        df_tenancies_rent_reviews = df_tenancies_rent_reviews.append(df, ignore_index=True)
        
# Only confirmed rent reviview
#df_tenancies_rent_reviews = df_tenancies_rent_reviews[df_tenancies_rent_reviews['Confirmed'] == True]
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\437004559.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\437004559.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tenancies_rent_reviews = df_tenancies_rent_reviews.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\437004559.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\437004559.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# # 3. Owners.csv

# %%
def get_landlord_details(prop_id):
    url = f"https://webservice.reapit.net.au/lng/rest/properties/{prop_id}/landlord"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/properties/{prop_id}?GetUnavailable=true/landlord"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_landlords = pd.DataFrame()
for prop_id in pt_df_properties['property_id'].tolist():
    result = get_landlord_details(prop_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        df.insert(0, 'prop_id', prop_id)
        
        
        # Append the DataFrame to df_result
        df_landlords = df_landlords.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3738337966.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3738337966.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_landlords = df_landlords.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3738337966.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3738337966.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_landlords = df_landlords.append(df, ignore_index=True)
# ...

# %%
# Append the columns which contains contacts in the owners ID
for index,row in df_landlords.iterrows():
    for i in range(len(row['Ownership'])):
        df_landlords.loc[index,f"contact_{i+1}_id"] = row['Ownership'][i]['Contact']['ID']

#df_landlords['Ownership'].iloc[0]

# %% [markdown]
# # 4. Generating Contacts since for the owners csv we will use properties from contacts

# %%
#Appending the IDs for Joint Tenants

contacts_id_list = []

# To get the IDs of Joint contact

for value in df_tenancies['JointTenant']:
    if str(value) != 'nan':  # Check if the value is not NaN
        ids = [entry['ID'] for entry in value]  # Extract the IDs from the list of dictionaries
        contacts_id_list.extend(ids)  # Append the IDs to the list

# %%
# Appending the Tenants ID

ids = [value for value in df_tenancies['Tenant_ID'] if str(value) != 'nan']  # Extract the IDs from the list of dictionaries
contacts_id_list.extend(ids)  # Append the IDs to the list

# %%
# Appeding the landlords contacts

for index, row in df_landlords.iterrows():
    
    contacts_id_list.extend([x["ID"] for x in row['Contact']])
    
contacts_id_list = list(set(contacts_id_list))

# %%
def get_contact_details(contact_id):
    url = f"https://webservice.reapit.net.au/lng/rest/contacts/{contact_id}?IncludeArchive=true"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/contacts/{contact_id}?IncludeArchive=true?GetUnavailable=true"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_contacts = pd.DataFrame()
for contact_id in contacts_id_list:
    result = get_contact_details(contact_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        
        # Append the DataFrame to df_result
        df_contacts = df_contacts.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2769643102.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2769643102.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_contacts = df_contacts.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2769643102.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2769643102.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_contacts = df_contacts.append(df, ignore_index=True)
# ...

# %%
df_contacts[df_contacts['Initials'].isna()]
# Out:
#                       ID Title Initials                              Surname  \
# 16   rps_lng-HDO21001254   NaN      NaN                                  NaN
# 18   rps_lng-HDO22001892   NaN      NaN  ATF Shanti Meena Bell Holding Trust
# 21   rps_lng-CVA21001679   NaN      NaN                                  NaN
# 30   rps_lng-HDO19005556   NaN      NaN                                  NaN
# 56   rps_lng-CVA21001738   NaN      NaN                                  NaN
# 72   rps_lng-CVA21001725   NaN      NaN                                  NaN
# 86   rps_lng-HDO23000632   NaN      NaN                                  NaN
# 106  rps_lng-HDO23000731   NaN      NaN                                  NaN
# 148  rps_lng-HDO21002568   NaN      NaN                                  NaN
# 154  rps_lng-HDO21003002   NaN      NaN                                  NaN
# 162  rps_lng-HDO19003167   NaN      NaN                                  NaN
# ...

# %%
df_landlords['Contact'].apply(lambda x: len(x)).value_counts()
# Out:
# 1    155
# 2    103
# Name: Contact, dtype: int64

# %% [markdown]
# ### 4.2 Generating CSV for contacts

# %%
df_contacts_mapping = {
    'contact_id': 'ID',
    'title': 'Title',
    'given_name': 'Initials',
    'family_name': 'Surname',
    'preferred_name': '',
    'address_unit': '',
    'address_street_no': 'HouseNumber',
    'address_street_1': 'Address1',
    'address_street_2': '',
    'address_suburb': 'Address3',
    'address_state': 'Address4',
    'address_postcode': 'Postcode',
    'address_country': 'Country',
    'mailing_address_unit': '',
    'mailing_address_street_no': '',
    'mailing_address_street_1': '',
    'mailing_address_street_2': '',
    'mailing_address_suburb': '',
    'mailing_address_state': '',
    'mailing_address_postcode': '',
    'mailing_address_country': '',
    'preferred_email': 'Email',
    'preferred_phone': 'Mobile',
    'additional_emails': '',
    'additional_phones': '',
    'other_contact_info': ''
}
pt_df_contacts = pd.DataFrame()
for key,value in df_contacts_mapping.items():
    if value != '':
        pt_df_contacts[key] = df_contacts[value]
    else:
        pt_df_contacts[key] = ''
pt_df_contacts.loc[pt_df_contacts['preferred_phone'].notnull(), 'preferred_phone'] = 'Mobile ' + pt_df_contacts['preferred_phone'].astype(str)
def combine_values_contacts(row):
    values = []
    if pd.notnull(row['WorkPhone']):
        values.append('Work ' + str(row['WorkPhone']))
    if pd.notnull(row['Fax']):
        values.append('Fax ' + str(row['Fax']))
    if pd.notnull(row['HomePhone']):
        values.append('Home ' + str(row['HomePhone']))
    return ' '.join(values)

pt_df_contacts['additional_phones'] = df_contacts.apply(combine_values_contacts, axis=1)
for index,row in pt_df_contacts.iterrows():
    
    if '/' in str(row['address_street_no']):
        #print(row['address_street_no'])
        
        pt_df_contacts.loc[index,'address_unit'] = row['address_street_no'].split('/')[1]
        pt_df_contacts.loc[index,'address_street_no'] = row['address_street_no'].split('/')[0]
    #print(row['address_suburb'].split())
    if str(row['address_suburb']) != 'nan':
        if len(row['address_suburb'].split()) >= 3:
            pt_df_contacts.loc[index,'address_postcode'] = row['address_suburb'].split()[-1]
            pt_df_contacts.loc[index,'address_state'] = row['address_suburb'].split()[-2]
            pt_df_contacts.loc[index,'address_suburb'] = ' '.join(row['address_suburb'].split()[:-2])

# %%
pt_df_contacts[pt_df_contacts['contact_id'] == 'rps_lng-CVA21000460'][['address_suburb','address_postcode','address_state']]
# Out:
#     address_suburb address_postcode address_state
# 19  UNITED KINGDOM                            NaN

# %%
pt_df_contacts = pt_df_contacts.dropna(subset=['given_name'])
pt_df_contacts.to_csv('PropertyTree Data/PropertyTree_Contacts.csv',index = False)

# %% [markdown]
# ### 4.3 Generating owners.csv

# %%
df_landlords.columns
# Out:
# Index(['ID', 'Contact', 'MarketingOptOut', 'IsTrackerUser', 'IsErased',
#        'PropertiesToLet', 'Ownership', 'Negotiator_ID', 'contact_1_id',
#        'contact_2_id'],
#       dtype='object')

# %%
df_landlords_mapping = {
    'ownership_id': 'ID',
    'prop_id': 'prop_id',
    'name': '',
    'abn': '',
    'gst_registered': '',
    'withhold_type': '',
    'withhold_amount': '',
    'withhold_reason': '',
    'increase_withhold_amount': '',
    'contact_1_id': 'contact_1_id',
    'contact_2_id' : 'contact_2_id',
    'contact_1_create_statements': '',
    'contact_1_send_statement_by': '',
    'contact_2_send_statement_by': '',
    'contact_1_statement_style': '',
    'contact_2_statement_style': '',
    'contact_1_type': '',
    'contact_2_type': '',
    'contact_1_payment_method': '',
    'contact_1_cheque_pay_to': '',
    'contact_1_account_name': '',
    'contact_1_account_bsb': '',
    'contact_1_account_no': '',
    'contact_1_eft_reference': '',
    'contact_1_payment_amount': '',
    'contact_2_payment_method': '',
    'contact_2_cheque_pay_to': '',
    'contact_2_account_name': '',
    'contact_2_account_bsb': '',
    'contact_2_account_no': '',
    'contact_2_eft_reference': '',
    'contact_2_payment_amount': '',
    'tag_[group name]': '',
    'fee_[fee id]': ''
}
pt_df_owners = pd.DataFrame()
for key,value in df_landlords_mapping.items():
    if value != '':
        pt_df_owners[key] = df_landlords[value]
    else:
        pt_df_owners[key] = ''

# %%
df_contacts[df_contacts['Initials'].isnull()]
# Out:
#                       ID Title Initials                              Surname  \
# 16   rps_lng-HDO21001254   NaN      NaN                                  NaN
# 18   rps_lng-HDO22001892   NaN      NaN  ATF Shanti Meena Bell Holding Trust
# 21   rps_lng-CVA21001679   NaN      NaN                                  NaN
# 30   rps_lng-HDO19005556   NaN      NaN                                  NaN
# 56   rps_lng-CVA21001738   NaN      NaN                                  NaN
# 72   rps_lng-CVA21001725   NaN      NaN                                  NaN
# 86   rps_lng-HDO23000632   NaN      NaN                                  NaN
# 106  rps_lng-HDO23000731   NaN      NaN                                  NaN
# 148  rps_lng-HDO21002568   NaN      NaN                                  NaN
# 154  rps_lng-HDO21003002   NaN      NaN                                  NaN
# 162  rps_lng-HDO19003167   NaN      NaN                                  NaN
# ...

# %%
for index,row in pt_df_owners.iterrows():

    pt_df_owners.loc[index,'name'] = df_contacts[df_contacts['ID'] == row['contact_1_id']]["Initials"].iloc[0] +" " + df_contacts[df_contacts['ID'] == row['contact_1_id']]["Surname"].iloc[0] if df_contacts[df_contacts['ID'] == row['contact_1_id']]["CompanyName"].iloc[0] == '' else df_contacts[df_contacts['ID'] == row['contact_1_id']]["CompanyName"].iloc[0]
    pt_df_owners.loc[index,'contact_1_create_statements'] = df_contacts[df_contacts['ID'] == row['contact_1_id']]["MarketingOptIn"].iloc[0]

for index, row in pt_df_owners.iterrows():
    if row['contact_1_create_statements']:
        row['contact_1_send_statement_by'] = 'Email'
        row['contact_1_statement_style'] = 'Basic'
        row['contact_1_type'] = 'Owner'
pt_df_owners = pt_df_owners.drop_duplicates()
pt_df_owners.to_csv("PropertyTree Data/PropertyTree_Owners.csv",index=False)

# %% [markdown]
# ### 4.4 Generating Owners transactions
#
# Seems like properties and owners transactions are same

# %%
def get_landlord_transactions(landlord_id):
    url = f"https://webservice.reapit.net.au/lng/rest/landlords/{landlord_id}/transactions"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

# %%
df_landlords_transactions = pd.DataFrame()
for landlord_id in df_landlords['ID'].tolist():
    result = get_landlord_transactions(landlord_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        
        # Append the DataFrame to df_result
        df_landlords_transactions = df_landlords_transactions.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_38736\2152325667.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_38736\2152325667.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_landlords_transactions = df_landlords_transactions.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_38736\2152325667.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_38736\2152325667.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# # 5. Inspections

# %%
def get_tenancies_inspection(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}/inspections"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}/inspections?GetUnavailable=true"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")
            return None

# %%
df_tenancies_inspection = pd.DataFrame()
for tenancy_id in df_tenancies['ID'].tolist():
    result = get_tenancies_inspection(tenancy_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        df['Tenancy_ID'] = tenancy_id
        
        # Append the DataFrame to df_result
        df_tenancies_inspection = df_tenancies_inspection.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\30730407.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\30730407.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tenancies_inspection = df_tenancies_inspection.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\30730407.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\30730407.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ### 5.2 Generating CSV for Inspections

# %%
import datetime as dt

# %%
df_tenancies_inspection_mapping = {
    'property_id': 'Property_ID',
    'tenancy_id': 'Tenancy_ID',
    'status': 'Confirmed',
    'inspection_type': '', # Have 'Ingoing' as value
    'inspection_date': 'DateTime',
    'start_time': 'DateTime',
    'end_time': 'Duration',
    'general_note': 'FollowUpNotes',
    'owner_note': '',
    'owner_followup_item': '',
    'tenancy_note': '',
    'tenancy_action': ''
}

# Assuming the existing DataFrame is named 'existing_df'
existing_columns = df_tenancies_inspection.columns

# Create a new dictionary with non-empty values from df_tenancies_inspection_mapping
new_columns_dict = {key: value for key, value in df_tenancies_inspection_mapping.items() if value != ''}

# Create a new DataFrame with columns from the dictionary
new_df = df_tenancies_inspection[list(new_columns_dict.values())]

# Rename the columns with keys from the dictionary
new_df.columns = list(new_columns_dict.keys())


new_df['inspection_date'] = pd.to_datetime(new_df['inspection_date'], format='%Y-%m-%d')
new_df['start_time'] = pd.to_datetime(new_df['start_time'], format='%Y-%m-%d')

try:
    new_df['inspection_date'] = pd.to_datetime(new_df['inspection_date'], utc=True).dt.date
except pd._libs.tslibs.np_datetime.OutOfBoundsDatetime:
    print("Error: Invalid or out-of-range date values encountered.")

new_df['start_time'] = pd.to_datetime(new_df['start_time'], utc=True).dt.time


new_df['end_time'] = pd.to_timedelta(new_df.start_time.apply(lambda x: x.strftime('%H:%M:%S'))) +  pd.to_timedelta(new_df['end_time'], unit='s')

import numpy as np
new_df['status'] = np.where(new_df['status'], 'Confirmed', 'Closed')


new_df.insert(3, 'inspection_type', 'Routine')

new_df.to_csv("PropertyTree Data/PropertyTree_Inspections.csv", index=False)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2640057447.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['inspection_date'] = pd.to_datetime(new_df['inspection_date'], format='%Y-%m-%d')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\2640057447.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['start_time'] = pd.to_datetime(new_df['start_time'], format='%Y-%m-%d')
# ...

# %% [markdown]
# # 6. Maintenance.csv

# %%
def get_tenancies_workorders(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}/worksOrders"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}/worksOrders?GetUnavailable=true"
        headers = {
            'ApiKey': "c242c818604a72582f383ba23b2853d1",
            "Accept": "application/json"
        }

        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code} - {response.text}")

# %%
df_tenancies_workorders = pd.DataFrame()
for tenancy_id in df_tenancies['ID'].tolist():
    result = get_tenancies_workorders(tenancy_id)
    
    if result is not None:
        # Convert the result to a DataFrame
        df = json_normalize(result['Response'], sep='_')
        
        # Append the DataFrame to df_result
        df_tenancies_workorders = df_tenancies_workorders.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\446644657.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\446644657.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tenancies_workorders = df_tenancies_workorders.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\446644657.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\446644657.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ### 6.1 Generating CSV for maintenance

# %%
df_tenancies_workorders_mapping = {
    'property_id': 'Property_ID',
    'requested_by': 'Reporter',
    'access_contact': 'Reporter',
    'tenancy_id': 'Tenancy_ID',
    'summary': 'Description',
    'details': 'Description',
    'status': 'Status',
    'quote_request_creditor_ids': 'Contractor_ID',
    'work_order_creditor_id': 'Contractor_ID'
}
pt_df_tenancies_workorders = pd.DataFrame()
for key,value in df_tenancies_workorders_mapping.items():
    pt_df_tenancies_workorders[key] = df_tenancies_workorders[value]



pt_df_tenancies_workorders['requested_by'] = pt_df_tenancies_workorders['requested_by'].fillna('Agency').replace({
    'Tenant': 'Tenancy',
    'Other': 'Agency',
    'Landlord': 'Owner'
})
pt_df_tenancies_workorders['access_contact'] = pt_df_tenancies_workorders['requested_by']
pt_df_tenancies_workorders.loc[pt_df_tenancies_workorders['requested_by'] != 'Tenancy', 'tenancy_id'] = None

pt_df_tenancies_workorders['status'] = pt_df_tenancies_workorders['status'].replace({
    'Raised': 'Open',
    'Pending quote': 'QuoteRequest',
    'Pending approval': 'OwnerAttending',
    'Completed': 'WorkOrder'
})
pt_df_tenancies_workorders
# Out:
#            property_id requested_by access_contact tenancy_id  \
# 0    rps_lng-CVA210023       Agency         Agency       None
# 1    rps_lng-CVA210023       Agency         Agency       None
# 2    rps_lng-CVA210032       Agency         Agency       None
# 3    rps_lng-CVA210032       Agency         Agency       None
# 4    rps_lng-CVA210032       Agency         Agency       None
# ..                 ...          ...            ...        ...
# 847  rps_lng-HDO230072       Agency         Agency       None
# 848  rps_lng-HDO230086       Agency         Agency       None
# 849  rps_lng-HDO230187       Agency         Agency       None
# 850  rps_lng-HDO230187       Agency         Agency       None
# 851  rps_lng-HDO230313       Agency         Agency       None
#
#                                              summary  \
# 0                   Replacement of hot water service
# 1    Repair to courtyard door and holders in laundry
# 2                 Repair to plaster after water leak
# ...

# %%
pt_df_tenancies_workorders = pt_df_tenancies_workorders[pt_df_tenancies_workorders['work_order_creditor_id'].notnull()]

# %%
pt_df_tenancies_workorders.loc[pt_df_tenancies_workorders['status'] != 'QuoteRequest', 'quote_request_creditor_ids'] = None
pt_df_tenancies_workorders.loc[pt_df_tenancies_workorders['status'] != 'WorkOrder', 'work_order_creditor_id'] = None


pt_df_tenancies_workorders.to_csv("PropertyTree Data/PropertyTree_Maintenance.csv", index=False)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3201674874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_df_tenancies_workorders.loc[pt_df_tenancies_workorders['status'] != 'QuoteRequest', 'quote_request_creditor_ids'] = None
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\3201674874.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_df_tenancies_workorders.loc[pt_df_tenancies_workorders['status'] != 'WorkOrder', 'work_order_creditor_id'] = None

# %% [markdown]
# # 7. Creditors.csv (RUN after the invoice generated below)

# %%
pt_df_invoices
# Out:
#      invoice_type        property_id          creditor_id tenancy_id  \
# 0        Creditor  rps_lng-HDO190229  rps_lng-HDO12001504
# 1        Creditor  rps_lng-HDO190548  rps_lng-HDO12001444
# 2        Creditor  rps_lng-HDO190959  rps_lng-HDO12001504
# 3        Creditor  rps_lng-HDO190592  rps_lng-HDO13000942
# 4        Creditor  rps_lng-HDO190529  rps_lng-HDO07003797
# ...           ...                ...                  ...        ...
# 4734     Creditor  rps_lng-HDO150011  rps_lng-HDO19001785
# 4735     Creditor  rps_lng-HDO190592  rps_lng-HDO19002668
# 4736     Creditor  rps_lng-HDO190320  rps_lng-HDO19001188
# 4737     Creditor  rps_lng-HDO190320  rps_lng-HDO22004027
# 4738     Creditor  rps_lng-HDO190174  rps_lng-HDO22004027
#
#      entered_date   due_date                   creditor_reference is_priority  \
# 0      2021-01-04 2021-01-04       HDO20348280/T557052320 | 13039
# 1      2021-01-05 2021-01-05  HDO20348286/234531531 23583 | 13044
# ...

# %%
df_creditors = pd.DataFrame()
for contact_id in list(set(pt_df_invoices['creditor_id'].tolist())):
    if str(contact_id) != 'nan':
        result = get_contact_details(contact_id)
        
        if result is not None:
            # Convert the result to a DataFrame
            df = json_normalize(result['Response'], sep='_')
            
            # Append the DataFrame to df_result
            df_creditors = df_creditors.append(df, ignore_index=True)
# Out:
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\645695044.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\645695044.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_creditors = df_creditors.append(df, ignore_index=True)
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\645695044.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(result['Response'], sep='_')
# C:\Users\SahilSingh\AppData\Local\Temp\ipykernel_10780\645695044.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_creditors = df_creditors.append(df, ignore_index=True)
# ...

# %%
df_creditors['HouseNumber']
# Out:
# 0          NaN
# 1           12
# 2          NaN
# 3      4/22-30
# 4          NaN
#         ...
# 315        NaN
# 316        NaN
# 317        NaN
# 318        NaN
# 319      80-86
# Name: HouseNumber, Length: 320, dtype: object

# %% [markdown]
# ### 7.1 Generating CSV for Creditors

# %%
df_creditors_mapping = {
    'creditor_id': 'ID',
    'name': 'CompanyName',
    'company_name': 'CompanyName',
    'abn': '',
    'address_unit': 'HouseNumber',
    'address_street_no': 'HouseNumber',
    'address_street_1': 'Address1',
    'address_street_2': 'Address2',
    'address_suburb': 'Address3',
    'address_state': 'Address4',
    'address_postcode': 'Postcode',
    'mailing_address_unit': '',
    'mailing_address_street_no': '',
    'mailing_address_street_1': '',
    'mailing_address_street_2': '',
    'mailing_address_suburb': '',
    'mailing_address_state': '',
    'mailing_address_postcode': '',
    'preferred_email': 'Email',
    'preferred_phone': 'WorkPhone',
    'additional_emails': '',
    'additional_phones': 'Mobile',
    'other_contact_info': '',
    'preferred_comm_method': 'Email',
    'default_account_code': '',
    'is_gst_exempt': '',
    'is_priority': '',
    'is_strata_creditor': '',
    'strata_plan_number': '',
    'strata_building_name': '',
    'strata_self_managed': '',
    'strata_building_street_no': '',
    'strata_building_street_1': '',
    'strata_building_street_2': '',
    'strata_building_suburb': '',
    'strata_building_state': '',
    'strata_building_postcode': '',
    'payment_method': '',
    'cheque_pay_to': '',
    'eft_account_name': '',
    'eft_account_bsb': '',
    'eft_account_no': '',
    'bpay_reference': '',
    'contact_[n]_id': '',
    'contact_[n]_type': '',
    'tag_[group name]': ''
}
pt_df_creditors = pd.DataFrame()
for key,value in df_creditors_mapping.items():
    if value != '':
        pt_df_creditors[key] = df_creditors[value]
    else:
        pt_df_creditors[key] = ''

pt_df_creditors.loc[pt_df_creditors['preferred_phone'].notnull(), 'preferred_phone'] = 'Work ' + pt_df_creditors['preferred_phone'].astype(str)
pt_df_creditors['address_unit'] = pt_df_creditors['address_unit'].apply(lambda x: str(x).split('/')[0] if str(x).__contains__('/') else '')
pt_df_creditors['address_street_no'] = pt_df_creditors['address_street_no'].apply(lambda x: str(x).split('/')[1] if str(x).__contains__('/') else x)
pt_df_creditors['preferred_comm_method'] = 'Email'
def combine_values(row):
    values = []
    if pd.notnull(row['Mobile']):
        values.append('Mobile ' + str(row['Mobile']).replace(" ", ""))
    if pd.notnull(row['Fax']):
        values.append('Fax ' + str(row['Fax']).replace(" ", ""))
    if pd.notnull(row['HomePhone']):
        values.append('Home ' + str(row['HomePhone']).replace(" ", ""))
    return ' '.join(values)

pt_df_creditors['additional_phones'] = df_creditors.apply(combine_values, axis=1)

def fill_missing_preferred_phone(row):
    if pd.isna(row['preferred_phone']):
        additional_phones = row['additional_phones']
        if additional_phones and 'Mobile' in additional_phones:
            mobile_match = re.search(r'Mobile (\d+)', additional_phones)
            if mobile_match:
                return f"Mobile {mobile_match.group(1)}"
        elif additional_phones and 'Home' in additional_phones:
            mobile_match = re.search(r'Home (\d+)', additional_phones)
            if mobile_match:
                return f"Home {mobile_match.group(1)}"
    return row['preferred_phone']

# Apply the custom function to fill missing values in 'preferred_phone'
pt_df_creditors['preferred_phone'] = pt_df_creditors.apply(fill_missing_preferred_phone, axis=1)

# %%
pt_df_creditors.to_csv("PropertyTree Data/PropertyTree_Creditors_with_Missing_Emails.csv",index=False)

# %%
pt_df_creditors[pt_df_creditors['preferred_email'].notnull()].to_csv("PropertyTree Data/PropertyTree_Creditors_clean.csv",index=False)

# %% [markdown]
# # 8. Invoices

# %%
df_properties_transactions
# Out:
#                         ID                   DateTime                Type  \
# 0                 rps_lng-  2021-02-02T00:00:00+00:00  Opening Balance CR
# 1      rps_lng-HDO21036047  2021-02-02T00:00:00+00:00            Transfer
# 2      rps_lng-HDO21042860  2021-02-05T00:00:00+00:00             Payment
# 3      rps_lng-HDO21032647  2021-02-05T15:12:53+00:00             Invoice
# 4      rps_lng-HDO21032670  2021-02-05T15:12:53+00:00             Invoice
# ...                    ...                        ...                 ...
# 31172  rps_lng-HDO23272032  2023-07-04T15:23:20+01:00             Invoice
# 31173  rps_lng-HDO23272035  2023-07-04T15:23:20+01:00             Invoice
# 31174  rps_lng-HDO23305617  2023-07-14T00:00:00+01:00             Invoice
# 31175  rps_lng-HDO23320042  2023-07-29T00:00:00+01:00             Invoice
# 31176  rps_lng-HDO23320045  2023-07-29T00:00:00+01:00             Invoice
#
#                    Category  \
# 0                     Float
# ...

# %%
df_invoices = df_tenancies_workorders[df_tenancies_workorders['Status'] == 'Completed']

# %%
df_tenancies_workorders.iloc[0]['SupplierInvoice']
# Out:
# [{'ID': 'rps_lng-HDO22065015',
#   'DateTime': '2022-07-27T09:52:53+01:00',
#   'Type': 'Invoice',
#   'FileName': 'Plumbing Force Pty Ltd Invoice #16014.pdf'}]

# %%
df_invoices
# Out:
#                        ID     Status   OrderDate                TimeAmended  \
# 0     rps_lng-VAD22001359  Completed  2022-07-20  2022-07-27T09:51:55+01:00
# 1     rps_lng-VAD22000970  Completed  2022-05-26  2022-08-25T11:43:13+01:00
# 3     rps_lng-HDO22002566  Completed  2022-11-28  2023-01-03T13:28:42+00:00
# 4     rps_lng-SAN22000323  Completed  2022-02-04  2022-12-01T09:45:54+00:00
# 5     rps_lng-DRE22000049  Completed  2022-01-11  2023-04-13T10:58:22+01:00
# ...                   ...        ...         ...                        ...
# 1205  rps_lng-JAM23000413  Completed  2023-05-01  2023-05-13T21:46:16+01:00
# 1207  rps_lng-WES23000236  Completed  2023-03-17  2023-07-11T18:49:33+01:00
# 1209  rps_lng-JAM23000424  Completed  2023-05-02  2023-05-10T12:52:10+01:00
# 1210  rps_lng-HDO23002575  Completed  2023-05-17  2023-05-30T12:52:49+01:00
# 1211  rps_lng-HDO23002576  Completed  2023-05-17  2023-05-24T13:23:21+01:00
#
# ...

# %% [markdown]
# ### 8.1 Generating CSV for Invoices

# %%
# import pandas as pd
# from fuzzywuzzy import fuzz 
# highest_ratio = -1
# best_match = None

# for index, row in df_invoices.iterrows():
#     highest_ratio = -1
#     best_match = None
#     for value2 in df_accounts['name']:
#         ratio = fuzz.ratio(row['Description'], value2)
#         if ratio > highest_ratio:
#             highest_ratio = ratio
#             best_match = value2
#     df_invoices.at[index, 'account_desc'] = best_match


# def getting_account_code(text):
#     prompt = """What would be the best appropiate key as the output from the following dictionary for which the {text} should belong to based on the value of the dictionary. Just print the key value: expenses = {
#     'gardng': 'Gardening',
#     'cleann': 'Cleaning',
#     'debtor': 'Debtors Account',
#     'crdtor': 'Creditors Account',
#     'clnbnk': 'Bank Charges',
#     'blinds': 'Blinds',
#     'Poolmt': 'Pool Maintenance',
#     'lldacc': 'Landlord Account',
#     'manren': 'Management Renewal Fee',
#     'rntinc': 'Rental Income',
#     'genman': 'General Maintenance',
#     'eofysf': 'EOFY Statement Fee',
#     'actadm': 'Accounts Admin Fee',
#     'manfee': 'Management Fee',
#     'depinc': 'Deposit Income',
#     'electn': 'Electrical Repairs',
#     'waterr': 'Water Rates',
#     'apprep': 'Appliance Repairs',
#     'smkala': 'Smoke Alarm',
#     'stmfee': 'Statement Fee',
#     'advert': 'Advertising Fee',
#     'leafee': 'Leasing Fee',
#     'plumng': 'Plumbing',
#     'recfee': 'Recurring Admin Fees',
#     'elegas': 'Gas Charges',
#     'ocfees': 'Owners Corporation Fees',
#     'insure': 'Insurance',
#     'postag': 'Postage',
#     'dishon': 'Dishonour Fee',
#     'learen': 'Leasing Renewal Fee',
#     'cnlrts': 'Council Rates',
#     'loanac': 'Loan Account',
#     'tnttrn': 'Tenant Transfer Fee',
#     'keyacc': 'Keys and Remotes',
#     'leabrk': 'Lease Break Fee',
#     'genexp': 'General Expenses',
#     'htgclg': 'Heating & Cooling',
#     'landtx': 'Land Tax',
#     'lldflt': 'Landlord Float',
#     'pmgfee': 'Project Management Fee',
#     'rengif': 'Renter Gift',
#     'glazng': 'Glazing Charges',
#     'lldadm': 'Landlord Admin Charge',
#     'electr': 'Electricity Usage',
#     'gutcln': 'Gutter Cleaning',
#     'vcatfe': 'VCAT Fee',
#     'compen': 'Compensation',
#     'adjacc': 'Adjustment Account',
#     'reimbu': 'Reimbursements',
#     'badfee': 'Cancellation Fee',
#     'intrnt': 'Internet',
#     'pstctl': 'Credit Card Fee',
#     'remstr': 'Removals and Storage',
#     'garrep': 'Garage Repairs',
#     'lcksmt': 'Locksmith',
#     'matfee': 'Management Renewal Fee',
#     'floorg': 'Flooring',
#     'bndclm': 'Bond Claim',
#     'fencin': 'Fencing',
#     'keysacc': 'Keys account'
#     }"""

#     response = get_completion(prompt)

#     return re.findall(r'(?<=\")[^\"]+(?=\")', response)

# %%
df_invoices.columns
# Out:
# Index(['ID', 'Status', 'OrderDate', 'TimeAmended', 'CompletionDate',
#        'Description', 'EstimatedCost', 'ActualCost', 'SupplierInvoice',
#        'Contractor_ID', 'Contractor_CompanyName', 'Contractor_HouseNumber',
#        'Contractor_Address1', 'Contractor_Address3', 'Contractor_Address4',
#        'Contractor_Postcode', 'Contractor_Country', 'Contractor_WorkPhone',
#        'Contractor_Fax', 'Contractor_Email', 'Contractor_Mobile',
#        'Contractor_Office_ID', 'Contractor_MarketingOptOut',
#        'Contractor_MarketingOptIn', 'Contractor_MarketingConsentAsked',
#        'Contractor_IsVendor', 'Contractor_IsLandlord', 'Contractor_IsTenant',
#        'Contractor_IsTrackerUser', 'Contractor_IsArchived',
#        'Contractor_IsApplicant', 'Contractor_Negotiator_ID',
#        'Contractor_TimeAmended', 'Contractor_TimeRegistered',
#        'Contractor_IsErased', 'Property_ID', 'Property_Address1',
#        'Property_Address2', 'Property_Address3', 'Property_Address4',
# ...

# %%
#Make to Csv
df_invoices_mapping = {
    'invoice_type': 'SupplierInvoice',
    'property_id': 'Property_ID',
    'creditor_id': 'Contractor_ID',
    'tenancy_id': 'Tenancy_ID',
    'entered_date': 'OrderDate',
    'due_date': 'OrderDate',
    'creditor_reference': 'Description',
    'is_priority': '',
    'line_1_account_code': '',
    'line_1_description': '',
    'line_1_amount_due': 'ActualCost',
    'line_1_gst_due': '',
    'line_1_amount_paid': ''
}
pt_df_invoices = pd.DataFrame()
for key,value in df_invoices_mapping.items():
    if value != '':
        pt_df_invoices[key] = df_invoices[value]
    else:
        pt_df_invoices[key] = ''

pt_df_invoices['invoice_type'] = pt_df_invoices.apply(lambda row: 'Tenancy' if str(row['invoice_type']) == 'nan' else 'Creditor',axis = 1)


pt_df_invoices.loc[(pt_df_invoices['creditor_id'].isnull()) & (pt_df_invoices['invoice_type'] == 'Creditor'), 'invoice_type'] = 'Tenancy'
pt_df_invoices['line_1_gst_due'] = 0
pt_df_invoices['line_1_amount_paid'] = 0

pt_df_invoices.to_csv("PropertyTree Data/PropertyTree_Invoices.csv",index=False)

# %% [markdown]
# # 9 Extras: Generating documents

# %%
df_tenancies_workorders['SupplierInvoice'].tolist()

# %%
supplier_invoice_ids = []
for item in df_tenancies_workorders['SupplierInvoice'].tolist():
    if isinstance(item, list):
        for entry in item:
            supplier_invoice_ids.append(entry['ID'])


# Print the extracted IDs
print(len(supplier_invoice_ids))

# %%
df_tenancies_workorders[df_tenancies_workorders['Description'].str.contains('Smoke', case=False)]
# Out:
#                        ID     Status   OrderDate                TimeAmended  \
# 289   rps_lng-HDO23001161  Completed  2023-03-06  2023-03-06T14:04:29+00:00
# 350   rps_lng-JAM20000735  Completed  2020-07-14  2020-08-10T16:57:55+01:00
# 490   rps_lng-CHA19000206  Completed  2019-08-15  2019-09-26T16:32:36+01:00
# 750   rps_lng-HDO19000169  Completed  2019-06-18  2019-08-08T13:47:24+01:00
# 791   rps_lng-DRE23000639  Completed  2023-02-10  2023-02-24T16:27:30+00:00
# 973   rps_lng-JAM21000463  Completed  2021-04-23  2021-07-14T13:55:59+01:00
# 1041  rps_lng-JAM23000244  Completed  2023-03-06  2023-05-12T13:20:33+01:00
# 1146  rps_lng-HDO22000236  Completed  2022-03-30  2022-05-25T09:25:26+01:00
#
#      CompletionDate                                    Description  \
# 289      2023-03-06  Gas, Electrical and Smoke Alarms Safety Check
# 350      2020-08-10          SMOKE ALARM has water leaking from it
# 490      2019-09-26                             Smoke alarm checks
# ...

# %%
url = "https://webservice.reapit.net.au/lng/rest/landlord/properties/rps_lng-HDO200371/documents"
headers = {
    'ApiKey': "c242c818604a72582f383ba23b2853d1",
    "Accept": "application/json"
}


response = requests.get(url, headers=headers)
if response.status_code == 200:
    print("Done")
    #print(response.json())
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Done

# %%
response.json()['Response']
# Out:
# [{'ID': 'rps_lng-HDO23018267',
#   'DateTime': '2023-02-23T11:22:45+00:00',
#   'Type': 'Letter',
#   'FileName': 'Hikvision_IP_Intercom_-_Basic_Functions (1).pdf'},
#  {'ID': 'rps_lng-HDO23018266',
#   'DateTime': '2023-02-23T11:22:41+00:00',
#   'Type': 'Letter',
#   'FileName': 'Hikvision_IP_Intercom_-_Extended_Functions (1).pdf'},
#  {'ID': 'rps_lng-WES21009582',
#   'DateTime': '2021-12-17T10:53:57+00:00',
#   'Type': 'Letter',
#   'FileName': 'FW PS608199K - IMPORTANT - Welcome to Building Link - 109 Clarendon Street, Southbank.msg'},
#  {'ID': 'rps_lng-WES21009581',
#   'DateTime': '2021-12-17T10:53:53+00:00',
#   'Type': 'Letter',
#   'FileName': 'BuildingLink - General Brochure.pdf'},
#  {'ID': 'rps_lng-WES21009580',
#   'DateTime': '2021-12-17T10:53:50+00:00',
#   'Type': 'Letter',
#   'FileName': '20211213 - Welcome to Buildinglink Notice.pdf'},
#  {'ID': 'rps_lng-WES21009579',
#   'DateTime': '2021-12-17T10:53:48+00:00',
#   'Type': 'Letter',
# ...

# %%
# To get the Vendors Documents

url = "https://webservice.reapit.net.au/lng/rest/tenant/documents/rps_lng-HDO21294778"
headers = {
    'ApiKey': "c242c818604a72582f383ba23b2853d1",
    "Accept": "application/json"
}


response = requests.get(url, headers=headers)
if response.status_code == 200:
    print("Done")
    #print(response.json())
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Error: 404 - {"error":[{"message":"Document not found rps_lng-HDO21294778"}]}

# %%
# df_tenancies_transactions[df_tenancies_transactions['Type'] == 'Invoice']

# %%
#!pip install PyPDF2
from PyPDF2 import PdfReader

# %%
import base64

base64String = response.json()['Response']['message']
with open('temp.pdf', 'wb') as theFile:
  theFile.write(base64.b64decode(base64String))

# %%
theFile.close()

# %%
from io import BytesIO
import re
decoded_bytes = base64.b64decode(base64String)

# Load the PDF from the decoded bytes
pdf = PdfReader(BytesIO(decoded_bytes))

# Extract text from each page of the PDF
text = ""
for page in pdf.pages:
    text += page.extract_text()

amount = None
amount_pattern = r'(\d+\.\d{2})'  # Assuming the amount has a decimal part with 2 digits
matches = re.findall(amount_pattern, text)
if matches:
    amount = matches[0]

print("Extracted Amount:", amount)
# Out:
# incorrect startxref pointer(1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44000\125651660.py in <module>
#       8 # Extract text from each page of the PDF
#       9 text = ""
# ---> 10 for page in pdf.pages:
#      11     text += page.extract_text()
#      12
#
# c:\Users\SahilSingh\anaconda3\lib\site-packages\PyPDF2\_page.py in __iter__(self)
#    2079
#    2080     def __iter__(self) -> Iterator[PageObject]:
# -> 2081         for i in range(len(self)):
#    2082             yield self[i]
#    2083
#
# c:\Users\SahilSingh\anaconda3\lib\site-packages\PyPDF2\_page.py in __len__(self)
#    2061
#    2062     def __len__(self) -> int:
# -> 2063         return self.length_function()
#    2064
#    2065     def __getitem__(self, index: int) -> PageObject:
#
# ...

# %%
text
# Out:
# ''

# %%
import openai

import os

import pandas as pd

import time

openai.api_key = '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'

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):

    messages = [{"role": "user", "content": prompt}]

    response = openai.ChatCompletion.create(

    model=model,

    messages=messages,

    temperature=0,

    )

    return response.choices[0].message["content"]

# %%
prompt = """What would be the best appropiate key as the output from the following dictionary for which the "URGENT - Shower Screen" should belong to based on the value of the dictionary. Just print the key value: expenses = {
    'gardng': 'Gardening',
    'cleann': 'Cleaning',
    'debtor': 'Debtors Account',
    'crdtor': 'Creditors Account',
    'clnbnk': 'Bank Charges',
    'blinds': 'Blinds',
    'Poolmt': 'Pool Maintenance',
    'lldacc': 'Landlord Account',
    'manren': 'Management Renewal Fee',
    'rntinc': 'Rental Income',
    'genman': 'General Maintenance',
    'eofysf': 'EOFY Statement Fee',
    'actadm': 'Accounts Admin Fee',
    'manfee': 'Management Fee',
    'depinc': 'Deposit Income',
    'electn': 'Electrical Repairs',
    'waterr': 'Water Rates',
    'apprep': 'Appliance Repairs',
    'smkala': 'Smoke Alarm',
    'stmfee': 'Statement Fee',
    'advert': 'Advertising Fee',
    'leafee': 'Leasing Fee',
    'plumng': 'Plumbing',
    'recfee': 'Recurring Admin Fees',
    'elegas': 'Gas Charges',
    'ocfees': 'Owners Corporation Fees',
    'insure': 'Insurance',
    'postag': 'Postage',
    'dishon': 'Dishonour Fee',
    'learen': 'Leasing Renewal Fee',
    'cnlrts': 'Council Rates',
    'loanac': 'Loan Account',
    'tnttrn': 'Tenant Transfer Fee',
    'keyacc': 'Keys and Remotes',
    'leabrk': 'Lease Break Fee',
    'genexp': 'General Expenses',
    'htgclg': 'Heating & Cooling',
    'landtx': 'Land Tax',
    'lldflt': 'Landlord Float',
    'pmgfee': 'Project Management Fee',
    'rengif': 'Renter Gift',
    'glazng': 'Glazing Charges',
    'lldadm': 'Landlord Admin Charge',
    'electr': 'Electricity Usage',
    'gutcln': 'Gutter Cleaning',
    'vcatfe': 'VCAT Fee',
    'compen': 'Compensation',
    'adjacc': 'Adjustment Account',
    'reimbu': 'Reimbursements',
    'badfee': 'Cancellation Fee',
    'intrnt': 'Internet',
    'pstctl': 'Credit Card Fee',
    'remstr': 'Removals and Storage',
    'garrep': 'Garage Repairs',
    'lcksmt': 'Locksmith',
    'matfee': 'Management Renewal Fee',
    'floorg': 'Flooring',
    'bndclm': 'Bond Claim',
    'fencin': 'Fencing',
    'keysacc': 'Keys account'
}"""

response = get_completion(prompt)

print(re.findall(r'(?<=\")[^\"]+(?=\")', response)[-1])
# Out:
# genman

# %%
prompt = f"Extract Due Date, Amount , Account name , GST from the text  : {text}"

response = get_completion(prompt)

print(response)
# Out:
# Due Date: Not mentioned in the text
# Amount: $148.50
# Account Name: Verve Maintenance
# GST: $13.50

# %%
response
# Out:
# 'Due Date: Not mentioned in the text\nAmount: $148.50\nAccount Name: Verve Maintenance\nGST: $13.50'

# %%
# !pip install pygwalker -q
# Out:
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\sahilsingh\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 35A Cameron Street transactions

# %%
import pandas as pd

# %%
cameron_tran = pd.read_excel("Data Before/35A Cameron Street Transactions.xlsx")
read_invoices = pd.read_csv("PropertyTree_Invoices.csv")

# %%
# df_invoices[df_invoices['Property_ID'] == 'rps_lng-CVA210023']

# %%
read_invoices
# Out:
#      invoice_type        property_id          creditor_id         tenancy_id  \
# 0        Creditor  rps_lng-CVA210023  rps_lng-CVA21001869  rps_lng-HDO211377
# 1         Tenancy  rps_lng-CVA210023                  NaN  rps_lng-HDO211377
# 2        Creditor  rps_lng-CVA210032  rps_lng-HDO19001188  rps_lng-CVA210538
# 3        Creditor  rps_lng-CVA210032  rps_lng-CVA21001869  rps_lng-CVA210538
# 4         Tenancy  rps_lng-CVA210032  rps_lng-CVA21001869  rps_lng-CVA210538
# ...           ...                ...                  ...                ...
# 1023     Creditor  rps_lng-HDO230065  rps_lng-HDO21001704  rps_lng-HDO230200
# 1024     Creditor  rps_lng-HDO230065  rps_lng-HDO18000912  rps_lng-HDO230200
# 1025     Creditor  rps_lng-HDO230086  rps_lng-HDO23001438  rps_lng-HDO230380
# 1026     Creditor  rps_lng-HDO230187  rps_lng-CVA21002238  rps_lng-JAM230003
# 1027     Creditor  rps_lng-HDO230187  rps_lng-DRE22000009  rps_lng-JAM230003
#
#      entered_date    due_date  \
# ...

# %%
cameron_tran[(cameron_tran['Type'] == 'Works Order Payment') & (cameron_tran['Authorisation Status'] == 'Rejected')]
# Out:
#           Date         Landlord                               Property  \
# 108 2021-09-23  Mr Lou Larubina  35A Cameron Street, COBURG, VIC, 3058
# 109 2021-09-23  Mr Lou Larubina  35A Cameron Street, COBURG, VIC, 3058
# 110 2021-09-23  Mr Lou Larubina  35A Cameron Street, COBURG, VIC, 3058
# 146 2021-11-15  Mr Lou Larubina  35A Cameron Street, COBURG, VIC, 3058
#
#                                        Supplier           Tenant  \
# 108                     Property Insurance Plus
# 109  Leaftop Garden & Property Services Pty Ltd  Sarah McPherson
# 110                       Moreland City Council
# 146                       Moreland City Council
#
#        Internal/External Reference Ledger                 Type  Net Amount  \
# 108      HDO21312153/37786 - 23756      S  Works Order Payment      340.00
# 109              SAN21000625/45947      S  Works Order Payment      550.00
# 110  HDO21294778/1707871 - 22695-1      S  Works Order Payment     1021.17
# ...

# %%
'''
To get te documents for every tenancies
'''


def get_tenancies_documents(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/landlord/tenancies/{tenancy_id}/documents"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

# %%
import requests
def get_tenancies_workorders(tenancy_id):
    url = f"https://webservice.reapit.net.au/lng/rest/tenancies/{tenancy_id}/worksOrders"
    headers = {
        'ApiKey': "c242c818604a72582f383ba23b2853d1",
        "Accept": "application/json"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

# %%
get_tenancies_documents('rps_lng-HDO211377')
# Out:
# {'Response': [{'ID': 'rps_lng-VAD23004663',
#    'DateTime': '2023-07-17T14:26:53+01:00',
#    'Type': 'Letter',
#    'FileName': 'Rent increase E to T.msg'},
#   {'ID': 'rps_lng-RPT23003972',
#    'DateTime': '2023-05-25T11:01:50+01:00',
#    'Type': 'Inspection Report',
#    'FileName': '2023-05-24 (Routine) 35A Cameron Street, COBURG 3058.pdf'},
#   {'ID': 'rps_lng-VAD22006263',
#    'DateTime': '2022-08-25T11:48:42+01:00',
#    'Type': 'Email',
#    'FileName': 'Rent review E to LL .msg'},
#   {'ID': 'rps_lng-VAD22006447',
#    'DateTime': '2022-08-25T11:48:40+01:00',
#    'Type': 'Email',
#    'FileName': 'Confirmed lease with LL .msg'},
#   {'ID': 'rps_lng-HDO22076452',
#    'DateTime': '2022-08-30T15:21:39+01:00',
#    'Type': 'Letter',
#    'FileName': 'Renewal of Residential Renters Agreement - 35A Cameron Street Coburg VIC 3058.pdf'},
#   {'ID': 'rps_lng-HDO22070888',
#    'DateTime': '2022-08-16T12:17:48+01:00',
#    'Type': 'Letter',
# ...

# %%
df_tenancies[df_tenancies['Property_ID'] == 'rps_lng-CVA210023']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44000\775010188.py in <module>
# ----> 1 df_tenancies[df_tenancies['Property_ID'] == 'rps_lng-CVA210023']
#
# NameError: name 'df_tenancies' is not defined

# %% [markdown]
# # Reading the transactions for Kasey port folio from 1 jan ,2021 to 20 Aug, 2023 sections

# %%
import pandas as pd
kasey_transaction = pd.read_excel("Data Before/Transactions_Kasey_upd.xlsx")

# %%
kasey_transaction['Ledger'].unique()
# Out:
# array(['S'], dtype=object)

# %%
'35A Cameron Street, COBURG, VIC, 3058' in kasey_transaction[kasey_transaction['Type'] == 'Works Order Payment']['Property'].unique()
# Out:
# True

# %%
kasey_transaction= kasey_transaction[kasey_transaction['Authorisation Status'] != 'Rejected']

# %%
kasey_transaction[(kasey_transaction['Tenancy Code'] != ' ') & (kasey_transaction['Tenant'] != ' ')]
# Out:
#            Date                        Landlord  \
# 3    2021-01-05                 Ms Trudy Hooper
# 13   2021-01-08                   David Coulton
# 19   2021-01-13  Notsae Pty Ltd C/- M, Woodhead
# 25   2021-01-14                  Mr Vince Clegg
# 37   2021-01-19                     Jason Perry
# ...         ...                             ...
# 4733 2023-08-18                Leanne Custerson
# 4735 2023-08-18                 Ms Trudy Hooper
# 4736 2023-08-18                 Mr Keith Tomlin
# 4737 2023-08-18                 Mr Keith Tomlin
# 4738 2023-08-18                Michael Lisowiec
#
#                                                Property  \
# 3           4207/7 Riverside Quay, Southbank, VIC, 3006
# 13            G21/9 Hewitt Avenue, Footscray, Vic, 3011
# 19           52 Millswyn Street, South Yarra, Vic, 3141
# 25                16 Winona Circuit, Tarneit, Vic, 3029
# 37           28 Fellows Street, Melton South, VIC, 3338
# ...

# %%
#Make to Csv
df_invoices_mapping = {
    'invoice_type': 'Ledger',
    #'invoice_type': 'Tenant',
    'property_id': 'Property Code',
    'creditor_id': 'Supplier Code',
    'tenancy_id': 'Tenancy Code',
    'entered_date': 'Date',
    'due_date': 'Date',
    'creditor_reference': 'Internal/External Reference',
    'is_priority': '',
    'line_1_account_code': 'CR Code',
    'line_1_description': 'Description',
    'line_1_amount_due': 'Net Amount',
    'line_1_gst_due': 'GST Amount',
    'line_1_amount_paid': 'Debit'
}
pt_df_invoices = pd.DataFrame()
for key,value in df_invoices_mapping.items():
    if value != '':
        pt_df_invoices[key] = kasey_transaction[value]
    else:
        pt_df_invoices[key] = ''

pt_df_invoices['invoice_type'] = pt_df_invoices.apply(lambda row: 'Tenancy' if str(row['invoice_type']) != 'S' else 'Creditor',axis = 1)
#pt_df_invoices['invoice_type'] = pt_df_invoices.apply(lambda row: 'Tenancy' if row['tenancy_id'] != ' ' and row['invoice_type'] != ' '  else 'Creditor',axis = 1)
#kasey_transaction[(kasey_transaction['Tenancy Code'] != ' ') & (kasey_transaction['Tenant'] != ' ')]
pt_df_invoices['property_id'] = pt_df_invoices.apply(lambda row: ('rps_lng-' + str(row['property_id'])) if str(row['property_id']) != 'nan' else '',axis = 1)
pt_df_invoices['creditor_id'] = pt_df_invoices.apply(lambda row: ('rps_lng-' + str(row['creditor_id'])) if row['invoice_type'] != 'Tenancy' else '',axis = 1)
pt_df_invoices['tenancy_id'] = pt_df_invoices.apply(lambda row: ('rps_lng-' + str(row['tenancy_id'])) if row['invoice_type'] == 'Tenancy' else '',axis = 1)


#pt_df_invoices.loc[(pt_df_invoices['creditor_id'].isnull()) & (pt_df_invoices['invoice_type'] == 'Creditor'), 'invoice_type'] = 'Tenancy'
# pt_df_invoices['line_1_gst_due'] = 0
# pt_df_invoices['line_1_amount_paid'] = 0

#pt_df_invoices.to_csv("PropertyTree Data/PropertyTree_Invoices.csv",index=False)

# %%
pt_df_invoices
# Out:
#      invoice_type        property_id          creditor_id tenancy_id  \
# 0        Creditor  rps_lng-HDO190229  rps_lng-HDO12001504
# 1        Creditor  rps_lng-HDO190548  rps_lng-HDO12001444
# 2        Creditor  rps_lng-HDO190959  rps_lng-HDO12001504
# 3        Creditor  rps_lng-HDO190592  rps_lng-HDO13000942
# 4        Creditor  rps_lng-HDO190529  rps_lng-HDO07003797
# ...           ...                ...                  ...        ...
# 4734     Creditor  rps_lng-HDO150011  rps_lng-HDO19001785
# 4735     Creditor  rps_lng-HDO190592  rps_lng-HDO19002668
# 4736     Creditor  rps_lng-HDO190320  rps_lng-HDO19001188
# 4737     Creditor  rps_lng-HDO190320  rps_lng-HDO22004027
# 4738     Creditor  rps_lng-HDO190174  rps_lng-HDO22004027
#
#      entered_date   due_date                   creditor_reference is_priority  \
# 0      2021-01-04 2021-01-04       HDO20348280/T557052320 | 13039
# 1      2021-01-05 2021-01-05  HDO20348286/234531531 23583 | 13044
# ...

# %%
for prop_id in pt_df_invoices['property_id'].unique():
    if prop_id.split('rps_lng-')[1] not in properties_before[properties_before['Agent Name'] =='Kasey Neuendorf']['Reference'].tolist():
        print(prop_id)

# %%
pt_df_invoices.to_csv("PropertyTree Data/PropertyTree_Invoices.csv",index=False)

# %%
import requests

url = "https://webservice.reapit.net.au/lng/rest/contacts/rps_lng-HDO19002688?IncludeArchive=true"
headers = {
    'ApiKey': "c242c818604a72582f383ba23b2853d1",
    "Accept": "application/json"
}

response = requests.get(url, headers=headers)
if response.status_code == 200:
    print(response.json())
# Out:
# {'Response': {'ID': 'rps_lng-HDO19002688', 'Salutation': 'Andrew', 'CompanyName': 'Four Walls Painting & Decorating Pty Ltd', 'Address1': 'PO Box 74', 'Address3': 'Watsonia', 'Address4': 'VIC', 'Postcode': '3087', 'Country': 'AU', 'WorkPhone': '0412 765 210', 'Email': 'fwpd10@gmail.com', 'MarketingOptOut': False, 'MarketingOptIn': True, 'MarketingConsentAsked': False, 'IsVendor': False, 'IsLandlord': False, 'IsTenant': False, 'IsTrackerUser': False, 'IsArchived': False, 'IsApplicant': False, 'TimeAmended': '2021-01-05T12:05:32+00:00', 'TimeRegistered': '2019-04-05T14:41:04+01:00', 'IsErased': False}}

# %%
response.content
# Out:
# b'{"error":[{"message":"No properties found"}]}'

# %%
pt_df_properties
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39288\2541537339.py in <module>
# ----> 1 pt_df_properties
#
# NameError: name 'pt_df_properties' is not defined

# %% [markdown]
# # reading the fees from Monday Board a

# %%
import pandas as pd

# %%
fees_monday = pd.read_excel("Data Before/Fees_for_Properties.xlsx")

# %%
fees_monday.columns = fees_monday.iloc[1]

# %%
fees_monday = fees_monday[2:]

# %%
fees_monday= fees_monday[fees_monday['PM'] == 'Kasey Neuendorf']

# %%
fees_monday
# Out:
# 1                                            Name Subitems RPS Property Code  \
# 12    503/18 Hoff Boulevard, Southbank, VIC, 3006      NaN         HDO210296
# 21    1 Third Avenue, Hoppers Crossing, VIC, 3029      NaN         HDO210242
# 73     1/3 Coane Street, Oakleigh East, VIC, 3166      NaN         HDO220480
# 74    83 Madisons Avenue, Diggers Rest, VIC, 3427      NaN         HDO220157
# 75         15 Alderney Street, Tarneit, VIC, 3029      NaN         HDO210251
# ..                                            ...      ...               ...
# 162    68 Conservatory Drive, Deanside, VIC, 3336      NaN         HDO220707
# 163     68 St Boswells Avenue, Berwick, VIC, 3806      NaN         HDO230195
# 164         6A Butler Street, Essendon, VIC, 3040      NaN         HDO220482
# 165       7 Farrier Road, Wyndham Vale, VIC, 3024      NaN         HDO210498
# 167  7 Perivale Crescent, Wyndham Vale, VIC, 3024      NaN         HDO220131
#
# ...

# %%
fees_monday['Admin'].value_counts()
# Out:
# $5.50 (inc GST)    50
# Complimentary      10
# $5.50 inc gst       8
# $3.25 inc. GST      6
# $3.30 inc. GST      4
# $5.50 inc. GST      4
# 0                   3
# Waived              3
# $3.25 inc gst       1
# $4.40 inc GST       1
# $4.40 (inc GST)     1
# 0.00                1
# $5.50 (inc GST      1
# Name: Admin, dtype: int64

# %%
# fees_list =['Management%', 'Letting', 'Advertising',
#        'Renewal', 'TT_Transfer', 'Admin', 'EOFY_Statement',
#        'Leasing_cancellation']
# fees_list_with_frequency  = []
# for fees in fees_list:
#        if fees == 'EOFY_Statement':
#               fees_list_with_frequency.append('Property_Flat_Manual')
#        if fees == 'Admin':
              

#     fees_list_with_frequency.append('Property_' + 'WeekRent_' + fees)
#     fees_list_with_frequency.append('Property_' + 'PercentAnnual_' + fees)

# %%
# fees_list_with_frequency

# %%
df_accounts['name'].unique()
# Out:
# array(['Debtors Account', 'Creditors Account', 'Bank Charges',
#        'Deposit Income', 'Rental Income', 'Adjustment Account',
#        'Accounts Admin Fee', 'Landlord Account', 'Loan Account',
#        'Landlord Float', 'Bond Claim', 'Gardening', 'Cleaning',
#        'Pool Maintenance', 'General Maintenance', 'Appliance Repairs',
#        'Electrical Repairs', 'Plumbing', 'Garage Repairs',
#        'Glazing Charges', 'Gutter Cleaning', 'Locksmith', 'Flooring',
#        'Fencing', 'Smoke Alarm', 'Keys and Remotes', 'EOFY Statement Fee',
#        'Statement Fee', 'Advertising Fee', 'Management Fee',
#        'Leasing Fee', 'Leasing Renewal Fee', 'Dishonour Fee', 'VCAT Fee',
#        'Cancellation Fee', 'Management Renewal Fee', 'Credit Card Fee',
#        'Removals and Storage', 'Registered Mail', 'key cutting',
#        'Virtual Tour', 'Virtual Styling', 'Professioanl Photography',
#        'Floorplan', 'Tenant Transfer Fee', 'Lease Break Fee',
# ...

# %%
fee_mapping = {
    'Management Fee': 'Property_Percent_RentReceipted',
    'Leasing Fee': 'Property_Percent_NewTenancy',
    'Advertising Fee': 'Property_Flat_NewTenancy',
    'Management Renewal Fee': 'Property_Percent_LeaseRenewal',
    'Tenant Transfer Fee':'Tenancy_Flat_Manual',
    'Accounts Admin Fee': 'Property_Flat_Manual',
    'EOFY Statement Fee': 'Property_Flat_Manual',
    #'Compliance Fee': 'Property_Flat_Manual' #Need to talk about the 
}
# Create a DataFrame
data = []
c= 1 
fee_type = None
for key, fee_name in fee_mapping.items():
    if 'Management Fee' == key:
        amount = 6.60
    elif key == 'Leasing Fee':
        amount = 2.20
    elif key == 'Advertising Fee':
        amount = 400.00
    elif key =='Management Renewal Fee':
        amount = 220.00
    elif key == 'Tenant Transfer Fee':
        amount = 5.50
    elif  key == 'EOFY Statement Fee':
        amount = 30.00
    print(key)    
    data.append({
        'fee_id': c,
        'name': key,
        'fee_type': fee_name,
        'account_code': df_accounts[df_accounts['name'] ==key]['code'].iloc[0],
        'applies_to': None,
        'applies_to_new': None,
        'amount': amount,
        'include_gst': 1
    })
    c = c+1


# Create a DataFrame from the data
df_fees = pd.DataFrame(data)
# Out:
# Management Fee
# Leasing Fee
# Advertising Fee
# Management Renewal Fee
# Tenant Transfer Fee
# Accounts Admin Fee
# EOFY Statement Fee

# %%
df_fees
# Out:
#    fee_id                    name                        fee_type  \
# 0       1          Management Fee  Property_Percent_RentReceipted
# 1       2             Leasing Fee     Property_Percent_NewTenancy
# 2       3         Advertising Fee        Property_Flat_NewTenancy
# 3       4  Management Renewal Fee   Property_Percent_LeaseRenewal
# 4       5     Tenant Transfer Fee             Tenancy_Flat_Manual
# 5       6      Accounts Admin Fee            Property_Flat_Manual
# 6       7      EOFY Statement Fee            Property_Flat_Manual
#
#   account_code applies_to applies_to_new  amount  include_gst
# 0       300004       None           None     6.6            1
# 1       300005       None           None     2.2            1
# 2       300003       None           None   400.0            1
# 3       300010       None           None   220.0            1
# 4       300019       None           None     5.5            1
# 5       100007       None           None     5.5            1
# ...

# %%
# # Create a DataFrame
# data = []
# c= 1 
# for value in fees_list_with_frequency:
    
#     fee_id = c  # You can use a different method to generate a unique fee_id
#     fee_type = None
#     for key, fee_name in fee_mapping.items():
#         if value in fee_name:
#             fee_type_dic =  {v: k for k, v in code_description.items()}
#             fee_type = fee_type_dic.get(key)
#             break
#     if fee_type is not None:
#         name = None
#         if 'Management%' in value:
#             name = 'Management%'
#         elif 'Letting' in value:
#             name = 'Letting'
#         elif 'Advertising' in value:
#             name = 'Advertising'
#         elif 'Renewal' in value:
#             name = 'Renewal'
#         elif 'TT_Transfer' in value:
#             name = 'TT_Transfer'
#         elif 'Admin' in value:
#             name = 'Admin'
#         elif 'EOFY_Statement' in value:
#             name = 'EOFY_Statement'
#         elif 'Leasing_cancellation' in value:
#             name = 'Leasing_cancellation'
#         data.append({
#             'fee_id': fee_id,
#             'name': name,
#             'fee_type': fee_type,
#             'account_code': value,
#             'applies_to': None,
#             'applies_to_new': None,
#             'amount': None,
#             'include_gst': None
#         })
#     c= c+1

# # Create a DataFrame from the data
# df = pd.DataFrame(data)

# %%
df_fees['applies_to_new'] = 'Residential'
df_fees['applies_to'] = 'Residential'

# %%
df_fees.to_csv("PropertyTree Data/PropertyTree_Fees.csv",index = False)

# %% [markdown]
# # Compliances

# %%
import pandas as pd 
compliances  = pd.read_excel("Data Before/Compliance_upd_final.xlsx")

# %%
compliances = compliances[1:]
compliances.columns = compliances.iloc[0]

# %%
compliances = compliances[1:]

# %%
compliances.columns
# Out:
# Index(['Name', 'Subitems', 'RPS Property Code', 'PM ↘️', 'Agent ↘️',
#        'Min Standards', 'emailed certificate', 'Electrical Check', 'Ordered',
#        'Elec Expiry', 'Elec -Email to PM', 'Gas?', 'Gas Check', 'Gas Expiry',
#        'Gas Email to PM', 'Pool?', 'Pool Check', 'Pool Expiry',
#        'Pool - Email to PM', 'Smoke', 'Certificate Providedcomp',
#        'Smoke Expiry', 'Building Insurance', 'RACV EHA', 'Insurer',
#        'Bldg Expiry', 'Policy #', 'LL Insurance', 'LL Insurer', 'LL Expiry',
#        'LL Policy #', 'On Hold', 'Text'],
#       dtype='object', name=1)

# %%
compliances
# Out:
# 1                                                  Name Subitems  \
# 2        3/270 Blackburn Road, Glen Waverley, Vic, 3150      NaN
# 3     118/270 Springvale Road, Glen Waverley, VIC, 3150      NaN
# 4        6/270 Blackburn Road, Glen Waverley, Vic, 3150      NaN
# 5         502C/42-58 Nelson Street, Ringwood, VIC, 3134      NaN
# 6     123/270 Springvale Road, Glen Waverley, Vic, 3150      NaN
# ...                                                 ...      ...
# 3286         3/5 Somers Court, Glen Waverley, Vic, 3150      NaN
# 3287           41 Willowtree Drive, Pakenham, VIC, 3810      NaN
# 3288          2/20 Marriott Street, St Kilda, VIC, 3182      NaN
# 3289            16 Cavell Drive, Craigieburn, Vic, 3064      NaN
# 3290                                                NaN      NaN
#
# 1    RPS Property Code                  PM ↘️          Agent ↘️  \
# 2            HDO110157         Tanaiya Moussa    Tanaiya Moussa
# ...

# %%
rows = []
for index,row in compliances.iterrows():
    if row['Min Standards']:
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Minimum Standards',
         'compliance_type' : 'General',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': None,
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Min Standards :{row['Min Standards']}, Certificates :{row['emailed certificate']}"
         })
    if row['Electrical Check'] == 'Valid':
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Electrical',
         'compliance_type' : 'General',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Elec Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Electrical Check :{row['Electrical Check']}, Ordered :{row['Ordered']}"
         })
    if row['Gas?'] == 'Yes':
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Gas',
         'compliance_type' : 'General',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Gas Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Gas Check :{row['Gas Check']}"
         })
    if row['Pool?'] == 'Yes':
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Pool',
         'compliance_type' : 'General',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Pool Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Pool Check :{row['Pool Check']}"
         })
    if row['Smoke'] == 'SAA':
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Smoke',
         'compliance_type' : 'SmokeAlarm_Unknown',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Smoke Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Certificate Provided :{row['Certificate Providedcomp']}"
         })
    if row['Smoke'] == 'Other':
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Smoke',
         'compliance_type' : 'SmokeAlarm_Unknown',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Smoke Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Certificate Provided :{row['Certificate Providedcomp']}"
         })
    if row['Smoke'] == 'Landlord':
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Smoke',
         'compliance_type' : 'SmokeAlarm_Unknown',
         'managed_by': 'Owner',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Smoke Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Certificate Provided :{row['Certificate Providedcomp']}"
         })
    if row['Building Insurance'] in ['Current','Expiring'] :
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'Building Insurance',
         'compliance_type' : 'General',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['Bldg Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"Policy # :{row['Policy #']}, RACV EHA :{row['RACV EHA']}, Insurer :{row['Insurer']}"
         })
    if row['LL Insurance'] in ['Current','Expiring'] :
        rows.append({'property_id' : f"rps_lng-{row['RPS Property Code']}",
         'compliance category' : 'LL Insurance',
         'compliance_type' : 'General',
         'managed_by': 'Agent',
         'authority_form': 'Recieved',
         'service_by_creditor' : None,
         'expiry_date': row['LL Expiry'],
         'last_serviced': None,
         'next_service': None,
         'frequency': None,
         'reminder': None,
         'notes' : f"LL Policy # :{row['LL Policy #']}, Insurer :{row['LL Insurer']}"
         })

# %%
pt_compliances_all = pd.DataFrame(rows)

# %%
# Assuming pt_compliances_all and properties_before are your DataFrames
#split_values = pt_compliances_all['property_id'].str.split('_lng-').str[1]
# pt_compliances_based_on_props = pt_compliances_all[split_values.isin(properties_before[properties_before['Agent Name'] == 'Kasey Neuendorf']['Reference'])]

split_values = pt_compliances_all['property_id']
pt_compliances_based_on_props = pt_compliances_all[split_values.isin(pt_df_properties['property_id'].tolist())]

# %%
pt_compliances_based_on_props.to_csv("PropertyTree Data/PropertyTree_Compliances.csv",index=False)

# %%
import requests

# %%
url = "https://webservice.reapit.net.au/lng/rest/offices"
headers = {
    'ApiKey': "c242c818604a72582f383ba23b2853d1",
    "Accept": "application/json"
}

response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# {'Response': [{'ID': 'rps_lng-CSS', 'Name': 'Casuals'},
#   {'ID': 'rps_lng-GLD', 'Name': 'Gold'},
#   {'ID': 'rps_lng-GRS', 'Name': 'Guaranteed Rent'},
#   {'ID': 'rps_lng-GRL', 'Name': 'Guaranteed Rent Lite'},
#   {'ID': 'rps_lng-GRZ', 'Name': 'Guaranteed Rent Zero Arrears'},
#   {'ID': 'rps_lng-HAW', 'Name': 'Hawthorn'},
#   {'ID': 'rps_lng-HDO', 'Name': 'Head Office'},
#   {'ID': 'rps_lng-OVA', 'Name': 'Offshore VA'},
#   {'ID': 'rps_lng-RPT', 'Name': 'Reapit Office'},
#   {'ID': 'rps_lng-RNO', 'Name': 'Renovation'},
#   {'ID': 'rps_lng-RRP', 'Name': 'Rent Roll Purchased'},
#   {'ID': 'rps_lng-TBK', 'Name': 'Team Black'},
#   {'ID': 'rps_lng-SAN', 'Name': 'Team Blue'},
#   {'ID': 'rps_lng-JAM', 'Name': 'Team Green'},
#   {'ID': 'rps_lng-DRE', 'Name': 'Team Magenta'},
#   {'ID': 'rps_lng-TPP', 'Name': 'Team Purple'},
#   {'ID': 'rps_lng-VAD', 'Name': 'Team Red'},
#   {'ID': 'rps_lng-WES', 'Name': 'Team Yellow'}]}

# %%
url = "https://webservice.reapit.net.au/lng/rest/offices/rps_lng-RPT/negotiators"
headers = {
    'ApiKey': "c242c818604a72582f383ba23b2853d1",
    "Accept": "application/json"
}

response = requests.get(url, headers=headers)
response.json()
# Out:
# {'Response': [{'ID': 'rps_lng-RPT', 'Name': 'Reapit'},
#   {'ID': 'rps_lng-RPTA', 'Name': 'Scheduled Task'}]}
